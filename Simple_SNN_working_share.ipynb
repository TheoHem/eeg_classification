# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
import torch
import torch.nn as nn
import snntorch as snn
from snntorch import spikegen
from snntorch import surrogate
from prepare_dataset import *
from sklearn.model_selection import KFold
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, random_split
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
class SNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes, beta=0.9):
        super(SNN, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.lif1 = snn.Leaky(beta=beta, spike_grad=surrogate.fast_sigmoid())
        self.fc2 = nn.Linear(hidden_size, num_classes)
        self.lif2 = snn.Leaky(beta=beta, spike_grad=surrogate.fast_sigmoid())

    def forward(self, x):
        """
        Forward pass through the SNN using both spikes and membrane potentials.
        
        Parameters:
        - x: Input tensor of shape (batch_size, input_size, num_timesteps)
        
        Returns:
        - spk_rec: Spikes recorded over timesteps.
        - mem_rec: Membrane potentials recorded over timesteps.
        """
        # Initialize membrane potentials
        mem1 = self.lif1.init_leaky()
        mem2 = self.lif2.init_leaky()

        # Record spikes and membrane potentials
        spk_rec = []
        mem_rec = []
        #print(x.size())
        for step in range(x.size(2)):  # Iterate over time steps
            cur_input = x[:, :, step]  # Input at the current timestep

            # First layer
            mem1, spk1 = self.lif1(self.fc1(cur_input), mem1)

            # Second 
            mem2, spk2 = self.lif2(self.fc2(spk1), mem2)

            # Record spikes and membrane potentials
            spk_rec.append(spk2)
            mem_rec.append(mem2)

        return torch.stack(spk_rec, dim=2), torch.stack(mem_rec, dim=2)

# %%
class CSNN(nn.Module):
    def __init__(self, input_channels, num_classes, beta=0.9):
        super(CSNN, self).__init__()
        self.conv1 = nn.Conv2d(input_channels, 16, kernel_size=3, stride=1, padding=1)
        self.lif1 = snn.Leaky(beta=beta, spike_grad=surrogate.fast_sigmoid())
        
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
        self.lif2 = snn.Leaky(beta=beta, spike_grad=surrogate.fast_sigmoid())
        
        self.fc1 = nn.Linear(32 * 8 * 8, num_classes)  # Assuming 8x8 spatial size after pooling
        self.lif3 = snn.Leaky(beta=beta, spike_grad=surrogate.fast_sigmoid())
        
        self.pool = nn.AvgPool2d(2, 2)

    def forward(self, x):
        mem1 = self.lif1.init_leaky()
        mem2 = self.lif2.init_leaky()
        mem3 = self.lif3.init_leaky()

        spk_rec = []
        mem_rec = []

        for step in range(x.size(2)):
            cur_input = x[:, :, step, :, :]  # Assuming input shape: (batch, channels, timesteps, H, W)
            
            mem1, spk1 = self.lif1(self.conv1(cur_input), mem1)
            spk1 = self.pool(spk1)

            mem2, spk2 = self.lif2(self.conv2(spk1), mem2)
            spk2 = self.pool(spk2)

            spk2_flat = spk2.view(spk2.size(0), -1)  # Flatten for FC layer
            mem3, spk3 = self.lif3(self.fc1(spk2_flat), mem3)

            spk_rec.append(spk3)
            mem_rec.append(mem3)

        return torch.stack(spk_rec, dim=2), torch.stack(mem_rec, dim=2)

# %%
class RSNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes, beta=0.9):
        super(RSNN, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.lif1 = snn.Leaky(beta=beta, spike_grad=surrogate.fast_sigmoid())
        
        self.recurrent = nn.Linear(hidden_size, hidden_size)  # Recurrent layer
        self.lif2 = snn.Leaky(beta=beta, spike_grad=surrogate.fast_sigmoid())

        self.fc2 = nn.Linear(hidden_size, num_classes)
        self.lif3 = snn.Leaky(beta=beta, spike_grad=surrogate.fast_sigmoid())

    def forward(self, x):
        mem1 = self.lif1.init_leaky()
        mem2 = self.lif2.init_leaky()
        mem3 = self.lif3.init_leaky()

        spk_rec = []
        mem_rec = []

        rec_input = torch.zeros_like(mem2)  # Initialize recurrent input

        for step in range(x.size(2)):
            cur_input = x[:, :, step]

            mem1, spk1 = self.lif1(self.fc1(cur_input), mem1)

            # Add recurrent dynamics
            mem2, spk2 = self.lif2(self.recurrent(spk1) + rec_input, mem2)
            rec_input = spk2  # Feed spikes back to the next timestep

            mem3, spk3 = self.lif3(self.fc2(spk2), mem3)

            spk_rec.append(spk3)
            mem_rec.append(mem3)

        return torch.stack(spk_rec, dim=2), torch.stack(mem_rec, dim=2)

# %%
class SNN_3Layer(nn.Module):
    def __init__(self, input_size, hidden_size1, hidden_size2, num_classes, beta=0.9):
        super(SNN_3Layer, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.lif1 = snn.Leaky(beta=beta, spike_grad=surrogate.fast_sigmoid())
        
        self.fc2 = nn.Linear(hidden_size1, hidden_size2)
        self.lif2 = snn.Leaky(beta=beta, spike_grad=surrogate.fast_sigmoid())
        
        self.fc3 = nn.Linear(hidden_size2, num_classes)
        self.lif3 = snn.Leaky(beta=beta, spike_grad=surrogate.fast_sigmoid())

    def forward(self, x):
        mem1 = self.lif1.init_leaky()
        mem2 = self.lif2.init_leaky()
        mem3 = self.lif3.init_leaky()

        spk_rec = []
        mem_rec = []

        for step in range(x.size(2)):
            cur_input = x[:, :, step]

            mem1, spk1 = self.lif1(self.fc1(cur_input), mem1)
            mem2, spk2 = self.lif2(self.fc2(spk1), mem2)
            mem3, spk3 = self.lif3(self.fc3(spk2), mem3)

            spk_rec.append(spk3)
            mem_rec.append(mem3)

        return torch.stack(spk_rec, dim=2), torch.stack(mem_rec, dim=2)

# %%
class SNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes, beta=0.9):
        super(SNN, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.lif1 = snn.Leaky(beta=beta, spike_grad=surrogate.fast_sigmoid())
        self.fc2 = nn.Linear(hidden_size, num_classes)
        self.lif2 = snn.Leaky(beta=beta, spike_grad=surrogate.fast_sigmoid())

        spike_grad_lstm = surrogate.straight_through_estimator()

    def forward(self, x):
        """
        Forward pass through the SNN using both spikes and membrane potentials.
        
        Parameters:
        - x: Input tensor of shape (batch_size, input_size, num_timesteps)
        
        Returns:
        - spk_rec: Spikes recorded over timesteps.
        - mem_rec: Membrane potentials recorded over timesteps.
        """
        # Initialize membrane potentials
        mem1 = self.lif1.init_leaky()
        mem2 = self.lif2.init_leaky()

        # Record spikes and membrane potentials
        spk_rec = []
        mem_rec = []
        #print(x.size())
        for step in range(x.size(2)):  # Iterate over time steps
            cur_input = x[:, :, step]  # Input at the current timestep

            # First layer
            mem1, spk1 = self.lif1(self.fc1(cur_input), mem1)

            # Second 
            mem2, spk2 = self.lif2(self.fc2(spk1), mem2)

            # Record spikes and membrane potentials
            spk_rec.append(spk2)
            mem_rec.append(mem2)

        return torch.stack(spk_rec, dim=2), torch.stack(mem_rec, dim=2)

# %%
"""
All of the functions
"""

def compute_class_weights(train_loader):
    class_counts = np.zeros(4)  # Assuming 4 classes: Up, Down, Right, Left

    # Count occurrences of each class in the training dataset
    for _, labels in train_loader:
        for label in labels.cpu().numpy():
            class_counts[label] += 1

    # Inverse frequency
    class_weights = 1. / class_counts
    class_weights = class_weights / np.sum(class_weights)  # Normalize to sum to 1

    # Convert to tensor
    return torch.tensor(class_weights, dtype=torch.float32)

def plot_label_distribution(train_loader, val_loader, test_loader):
    """
    Plot label distribution for the train, validation, and test DataLoaders.

    Parameters:
    - train_loader: DataLoader for the training set.
    - val_loader: DataLoader for the validation set.
    - test_loader: DataLoader for the test set.
    """
    # Function to collect label frequencies
    def collect_labels(loader):
        labels = []
        for _, label_batch in loader:
            labels.extend(label_batch.cpu().numpy())
        return np.array(labels)

    # Collect labels from each dataset
    train_labels = collect_labels(train_loader)
    val_labels = collect_labels(val_loader)
    test_labels = collect_labels(test_loader)

    # Plot label distribution
    fig, ax = plt.subplots(1, 3, figsize=(15, 5))
    
    # Plotting for each dataset
    ax[0].hist(train_labels, bins=np.arange(5)-0.5, edgecolor="black", alpha=0.7)
    ax[0].set_title("Training Set Label Distribution")
    ax[0].set_xlabel("Class")
    ax[0].set_ylabel("Frequency")
    ax[0].set_xticks([0, 1, 2, 3])
    ax[0].set_xticklabels(["Up", "Down", "Right", "Left"])

    ax[1].hist(val_labels, bins=np.arange(5)-0.5, edgecolor="black", alpha=0.7)
    ax[1].set_title("Validation Set Label Distribution")
    ax[1].set_xlabel("Class")
    ax[1].set_ylabel("Frequency")
    ax[1].set_xticks([0, 1, 2, 3])
    ax[1].set_xticklabels(["Up", "Down", "Right", "Left"])

    ax[2].hist(test_labels, bins=np.arange(5)-0.5, edgecolor="black", alpha=0.7)
    ax[2].set_title("Test Set Label Distribution")
    ax[2].set_xlabel("Class")
    ax[2].set_ylabel("Frequency")
    ax[2].set_xticks([0, 1, 2, 3])
    ax[2].set_xticklabels(["Up", "Down", "Right", "Left"])

    plt.tight_layout()
    plt.show()


def create_data_loaders(dataset, train_frac=0.7, val_frac=0.2, test_frac=0.1, batch_size=16, shuffle=True):
    """
    Splits the dataset into training, validation, and test sets, and creates DataLoaders.
    
    Parameters:
    - dataset: The full dataset (TensorDataset).
    - train_frac: Fraction of the dataset to use for training.
    - val_frac: Fraction of the dataset to use for validation.
    - test_frac: Fraction of the dataset to use for testing.
    - batch_size: The batch size for the DataLoaders.
    - shuffle: Whether to shuffle the dataset.
    
    Returns:
    - train_loader: DataLoader for the training set.
    - val_loader: DataLoader for the validation set.
    - test_loader: DataLoader for the test set.
    """

    # Get dataset size
    total_size = len(dataset)
    
    # Calculate sizes for each subset
    train_size = int(total_size * train_frac)
    val_size = int(total_size * val_frac)
    test_size = total_size - train_size - val_size  # Remaining size for test set
    
    # Split the dataset into train, val, and test subsets
    train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size])
    
    # Create DataLoaders
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=shuffle)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=shuffle)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
    
    return train_loader, val_loader, test_loader

def train_snn(model, train_loader, val_loader, criterion, optimizer, num_epochs, device, patience=5):
    """
    Train and validate the SNN model, returning training and validation losses.
    
    Parameters:
    - model: The SNN model to train.
    - train_loader: DataLoader for the training set.
    - val_loader: DataLoader for the validation set.
    - criterion: The loss function.
    - optimizer: The optimizer to use.
    - num_epochs: The number of epochs to train.
    - device: The device ('cuda' or 'cpu') where the model is running.
    
    Returns:
    - train_losses: List of training losses for each epoch.
    - val_losses: List of validation losses for each epoch.
    """
    model.to(device)
    train_losses = []
    val_losses = []
    best_val_loss = float('inf')
    patience_counter = 0

    for epoch in range(num_epochs):
        model.train()
        total_train_loss = 0

        for batch_idx, (spikes, labels) in enumerate(train_loader):
            spikes, labels = spikes.to(device), labels.to(device)
            optimizer.zero_grad()

            spk_rec, mem_rec = model(spikes)
            num_timesteps = spk_rec.size(2)

            # Compute loss using membrane potential across all timesteps
            total_loss = torch.zeros(1, device=device)
            for step in range(num_timesteps):
                total_loss += criterion(mem_rec[:, :, step].squeeze(1), labels)  # Use membrane potential for loss

            total_loss /= num_timesteps  # Normalize by timesteps
            total_loss.backward()
            optimizer.step()

            total_train_loss += total_loss.item()

            print(f"Epoch [{epoch+1}/{num_epochs}], Batch [{batch_idx+1}/{len(train_loader)}], "
                  f"Train Loss: {total_loss.item():.4f}", end='\r')

        avg_train_loss = total_train_loss / len(train_loader)
        train_losses.append(avg_train_loss)

        # Validation phase
        model.eval()
        total_val_loss = 0
        correct = 0
        total = 0

        with torch.no_grad():
            for spikes, labels in val_loader:
                spikes, labels = spikes.to(device), labels.to(device)

                spk_rec, mem_rec = model(spikes)
                num_timesteps = spk_rec.size(2)

                # Compute validation loss using membrane potential across all timesteps
                total_loss = torch.zeros(1, device=device)
                for step in range(num_timesteps):
                    total_loss += criterion(mem_rec[:, :, step].squeeze(1), labels)  # Use membrane potential for loss

                total_loss /= num_timesteps
                total_val_loss += total_loss.item()

                # Calculate accuracy based on spike count
                spike_count = spk_rec.sum(dim=2)  # Sum spikes across all timesteps
                _, predicted = torch.max(spike_count, 1)  # Use spike count for accuracy
                correct += (predicted == labels).sum().item()
                total += labels.size(0)

        avg_val_loss = total_val_loss / len(val_loader)
        val_losses.append(avg_val_loss)
        val_accuracy = 100 * correct / total

        print(f"\nEpoch [{epoch+1}/{num_epochs}], "
              f"Train Loss: {avg_train_loss:.4f}, "
              f"Validation Loss: {avg_val_loss:.4f}, "
              f"Validation Accuracy: {val_accuracy:.2f}%")

        # Early stopping
        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print("Early stopping triggered.")
                break

    return train_losses, val_losses


def test_snn(model, test_loader, device):
    """
    Test the SNN model and return performance metrics including accuracy, precision, recall, F1 score, and confusion matrix.
    
    Parameters:
    - model: The trained SNN model.
    - test_loader: DataLoader for the test set.
    - device: The device ('cuda' or 'cpu') where the model is running.
    
    Returns:
    - accuracy: The accuracy of the model on the test set.
    - precision: Precision score.
    - recall: Recall score.
    - f1_score: F1 score.
    - confusion_matrix: The confusion matrix.
    """
    model.to(device)
    model.eval()  # Set model to evaluation mode

    all_labels = []
    all_preds = []
    total_correct = 0
    total = 0

    with torch.no_grad():
        for spikes, labels in test_loader:
            spikes, labels = spikes.to(device), labels.to(device)
            spk_rec, mem_rec = model(spikes)
            outputs = mem_rec[:, :, -1]  # Use last timestep for classification
            _, predicted = torch.max(outputs, 1)

            total_correct += (predicted == labels).sum().item()
            total += labels.size(0)

            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(predicted.cpu().numpy())

    accuracy = 100 * total_correct / total
    print(f"Test Accuracy: {accuracy:.2f}%")

    # Classification report with zero_division to handle undefined metrics
    print("\nClassification Report:")
    print(classification_report(all_labels, all_preds, target_names=["Up", "Down", "Right", "Left"], zero_division=1))

    # Confusion Matrix
    cm = confusion_matrix(all_labels, all_preds)
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Up", "Down", "Right", "Left"], yticklabels=["Up", "Down", "Right", "Left"])
    plt.title("Confusion Matrix")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()

    return accuracy, cm

# %%
root_dir = "data2/ds003626-2.1.2"

n_s = 1
model_type = "SNN"
fs = 256
Tstart = 1.5
Tend = 3.5
#encoding = "poisson"
encoding = "rate"

X, Y = create_dataset_for_all_subjects(root_dir, model_type, fs, Tstart, Tend, encoding)
# X shape (trials, channels, time)
#X, Y = create_dataset(root_dir, 1, model_type, fs, Tstart, Tend, encoding)

X = torch.tensor(X, dtype=torch.float32)  # Convert to tensor, adjust dtype if needed
Y = torch.tensor(Y, dtype=torch.long)    # Ensure labels are integers




train_data = torch.utils.data.TensorDataset(X, Y)
#train_loader = torch.utils.data.DataLoader(train_data, batch_size=16, shuffle=True)

train_loader, val_loader, test_loader = create_data_loaders(train_data, train_frac=0.6, val_frac=0.3, test_frac=0.1, batch_size=128, shuffle=True)


print(f'Batches in train, val, and test loader: {len(train_loader)}, {len(val_loader)}, {len(test_loader)}')
print(f'Samples in train, val, and test loader: {len(train_loader) * 16}, {len(val_loader)*16 }, {len(test_loader)*16}')
plot_label_distribution(train_loader, val_loader, test_loader)
# Out:
# Batches in train, val, and test loader: 11, 6, 2
# Samples in train, val, and test loader: 176, 96, 32

# %%
input_size = X.shape[1]  # Number of channels
hidden_size = 128  # Hidden layer size
num_classes = len(torch.unique(Y))  # Number of classes

# %%
beta = 0.9
spike_grad = surrogate.atan()

# %%
net = nn.Sequential(nn.Linear(input_size, hidden_size),
                    snn.Leaky(beta=beta, spike_grad=spike_grad, init_hidden=True),
                    nn.Linear(hidden_size, hidden_size),
                    snn.Leaky(beta=beta, spike_grad=spike_grad, init_hidden=True),
                    nn.Linear(hidden_size, hidden_size),
                    snn.Leaky(beta=beta, spike_grad=spike_grad, init_hidden=True),
                    #nn.Linear(hidden_size, hidden_size),
                    #snn.Leaky(beta=beta, spike_grad=spike_grad, init_hidden=True),
                    #nn.Linear(hidden_size, hidden_size),
                    #snn.Leaky(beta=beta, spike_grad=spike_grad, init_hidden=True),
                    nn.Linear(hidden_size, num_classes),
                    snn.Leaky(beta=beta, spike_grad=spike_grad, init_hidden=True, output=True)
                    )

# %%
def forward_pass(net, data):
  spk_rec = []
  utils.reset(net)  # resets hidden states for all LIF neurons in net

  for step in range(data.size(0)):  # data.size(0) = number of time steps
      spk_out, mem_out = net(data[step])
      spk_rec.append(spk_out)

  return torch.stack(spk_rec)

# %%
from snntorch import functional as SF
loss_fn = SF.mse_count_loss(correct_rate=0.8, incorrect_rate=0.2)
#loss = SF.ce_count_loss()
#optimizer = torch.optim.Adam(net.parameters(), lr=2e-2, betas=(0.9, 0.999))
optimizer = torch.optim.Adam(net.parameters())

# %%
loss_hist = []
acc_hist = []

loss_epoch = []
acc_epoch = []
eval_acc_epoch = []

# %%
from snntorch import utils
num_epochs = 100

for epoch in range(num_epochs):
    tmp_loss = []
    tmp_acc = []
    net.to(device)
    for i, (data, targets) in enumerate(iter(train_loader)):
        data = data.to(device)
        targets = targets.to(device)
        #print(data.size())
        #data = data.transpose(0,1).squeeze()
        data = data.permute(2, 0, 1)
        #print(data.size())
        net.train()
        spk_rec = forward_pass(net, data)
        loss = loss_fn(spk_rec, targets)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        loss_hist.append(loss.item())
        tmp_loss.append(loss.item())

        print(f"Epoch {epoch}, Iteration {i} \nTrain Loss: {loss.item():.2f}")

        acc = SF.accuracy_rate(spk_rec, targets)
        acc_hist.append(acc)
        tmp_acc.append(acc)
        print(f"Accuracy: {acc * 100:.2f}%\n")

        eval_acc = []
    for i, (data, targets) in enumerate(iter(val_loader)):
        data = data.to(device)
        targets = targets.to(device)
        data = data.permute(2, 0, 1)
        net.eval()
        spk_rec = forward_pass(net, data)

        acc = SF.accuracy_rate(spk_rec, targets)
        eval_acc.append(acc)
    eval_acc_tot = sum(eval_acc) / len(eval_acc)
    print(eval_acc_tot)
    print(f"Accuracy: {eval_acc_tot * 100:.2f}%\n")



    loss_epoch.append(sum(tmp_loss) / len(tmp_loss))
    acc_epoch.append(sum(tmp_acc) / len(tmp_acc))
    eval_acc_epoch.append(eval_acc_tot)
# Out:
# Epoch 0, Iteration 0
# Train Loss: 5.57
# Accuracy: 53.91%
#
# Epoch 0, Iteration 1
# Train Loss: 5.75
# Accuracy: 51.56%
#
# Epoch 0, Iteration 2
# Train Loss: 5.80
# Accuracy: 52.34%
#
# Epoch 0, Iteration 3
# Train Loss: 5.74
# Accuracy: 46.88%
#
# Epoch 0, Iteration 4
# Train Loss: 5.59
# Accuracy: 50.00%
#
# Epoch 0, Iteration 5
# Train Loss: 5.82
# Accuracy: 48.44%
#
# Epoch 0, Iteration 6
# Train Loss: 6.28
# Accuracy: 42.19%
#
# Epoch 0, Iteration 7
# Train Loss: 5.42
# Accuracy: 55.47%
#
# Epoch 0, Iteration 8
# Train Loss: 5.24
# Accuracy: 59.38%
#
# Epoch 0, Iteration 9
# Train Loss: 6.23
# Accuracy: 46.88%
#
# Epoch 0, Iteration 10
# Train Loss: 5.60
# Accuracy: 54.10%
#
# 0.27586805555555555
# Accuracy: 27.59%
#
# Epoch 1, Iteration 0
# Train Loss: 5.46
# Accuracy: 54.69%
#
# Epoch 1, Iteration 1
# Train Loss: 6.05
# Accuracy: 45.31%
#
# Epoch 1, Iteration 2
# Train Loss: 5.98
# Accuracy: 50.00%
#
# Epoch 1, Iteration 3
# Train Loss: 5.98
# Accuracy: 50.00%
#
# Epoch 1, Iteration 4
# Train Loss: 5.71
# Accuracy: 50.78%
#
# Epoch 1, Iteration 5
# Train Loss: 6.15
# Accuracy: 44.53%
#
# Epoch 1, Iteration 6
# Train Loss: 5.72
# Accuracy: 51.56%
#
# Epoch 1, Iteration 7
# Train Loss: 5.41
# Accuracy: 55.47%
#
# Epoch 1, Iteration 8
# Train Loss: 6.09
# Accuracy: 50.00%
#
# Epoch 1, Iteration 9
# Train Loss: 6.51
# Accuracy: 39.06%
#
# Epoch 1, Iteration 10
# Train Loss: 5.62
# Accuracy: 45.90%
#
# 0.2769097222222222
# Accuracy: 27.69%
#
# Epoch 2, Iteration 0
# Train Loss: 5.76
# Accuracy: 53.12%
#
# Epoch 2, Iteration 1
# Train Loss: 5.99
# Accuracy: 44.53%
#
# Epoch 2, Iteration 2
# Train Loss: 6.36
# Accuracy: 39.06%
#
# Epoch 2, Iteration 3
# Train Loss: 5.69
# Accuracy: 52.34%
#
# Epoch 2, Iteration 4
# Train Loss: 5.67
# Accuracy: 50.78%
#
# Epoch 2, Iteration 5
# Train Loss: 6.13
# Accuracy: 46.88%
#
# Epoch 2, Iteration 6
# Train Loss: 5.69
# Accuracy: 53.12%
#
# Epoch 2, Iteration 7
# Train Loss: 5.59
# Accuracy: 54.69%
#
# Epoch 2, Iteration 8
# Train Loss: 6.23
# Accuracy: 39.84%
#
# Epoch 2, Iteration 9
# Train Loss: 5.66
# Accuracy: 49.22%
#
# Epoch 2, Iteration 10
# Train Loss: 5.54
# Accuracy: 50.82%
#
# 0.25729166666666664
# Accuracy: 25.73%
#
# Epoch 3, Iteration 0
# Train Loss: 5.67
# Accuracy: 52.34%
#
# Epoch 3, Iteration 1
# Train Loss: 6.06
# Accuracy: 47.66%
#
# Epoch 3, Iteration 2
# Train Loss: 5.96
# Accuracy: 46.09%
#
# Epoch 3, Iteration 3
# Train Loss: 5.62
# Accuracy: 57.03%
#
# Epoch 3, Iteration 4
# Train Loss: 6.21
# Accuracy: 40.62%
#
# Epoch 3, Iteration 5
# Train Loss: 5.46
# Accuracy: 47.66%
#
# Epoch 3, Iteration 6
# Train Loss: 5.60
# Accuracy: 50.78%
#
# Epoch 3, Iteration 7
# Train Loss: 5.80
# Accuracy: 49.22%
#
# Epoch 3, Iteration 8
# Train Loss: 6.04
# Accuracy: 46.88%
#
# Epoch 3, Iteration 9
# Train Loss: 6.03
# Accuracy: 49.22%
#
# Epoch 3, Iteration 10
# Train Loss: 5.60
# Accuracy: 59.02%
#
# 0.25078125
# Accuracy: 25.08%
#
# Epoch 4, Iteration 0
# Train Loss: 5.75
# Accuracy: 52.34%
#
# Epoch 4, Iteration 1
# Train Loss: 6.11
# Accuracy: 38.28%
#
# Epoch 4, Iteration 2
# Train Loss: 6.14
# Accuracy: 44.53%
#
# Epoch 4, Iteration 3
# Train Loss: 5.64
# Accuracy: 53.91%
#
# Epoch 4, Iteration 4
# Train Loss: 5.83
# Accuracy: 53.12%
#
# Epoch 4, Iteration 5
# Train Loss: 5.81
# Accuracy: 47.66%
#
# Epoch 4, Iteration 6
# Train Loss: 5.67
# Accuracy: 50.78%
#
# Epoch 4, Iteration 7
# Train Loss: 5.17
# Accuracy: 54.69%
#
# Epoch 4, Iteration 8
# Train Loss: 5.61
# Accuracy: 53.91%
#
# Epoch 4, Iteration 9
# Train Loss: 6.19
# Accuracy: 42.19%
#
# Epoch 4, Iteration 10
# Train Loss: 5.93
# Accuracy: 50.82%
#
# 0.2765625
# Accuracy: 27.66%
#
# Epoch 5, Iteration 0
# Train Loss: 5.41
# Accuracy: 53.91%
#
# Epoch 5, Iteration 1
# Train Loss: 5.37
# Accuracy: 55.47%
#
# Epoch 5, Iteration 2
# Train Loss: 5.38
# Accuracy: 55.47%
#
# Epoch 5, Iteration 3
# Train Loss: 5.70
# Accuracy: 49.22%
#
# Epoch 5, Iteration 4
# Train Loss: 5.54
# Accuracy: 46.88%
#
# Epoch 5, Iteration 5
# Train Loss: 6.15
# Accuracy: 44.53%
#
# Epoch 5, Iteration 6
# Train Loss: 5.76
# Accuracy: 50.00%
#
# Epoch 5, Iteration 7
# Train Loss: 5.84
# Accuracy: 49.22%
#
# Epoch 5, Iteration 8
# Train Loss: 5.57
# Accuracy: 53.91%
#
# Epoch 5, Iteration 9
# Train Loss: 5.49
# Accuracy: 49.22%
#
# Epoch 5, Iteration 10
# Train Loss: 5.97
# Accuracy: 40.98%
#
# 0.2677951388888889
# Accuracy: 26.78%
#
# Epoch 6, Iteration 0
# Train Loss: 5.70
# Accuracy: 50.78%
#
# Epoch 6, Iteration 1
# Train Loss: 5.44
# Accuracy: 51.56%
#
# Epoch 6, Iteration 2
# Train Loss: 5.68
# Accuracy: 53.91%
#
# Epoch 6, Iteration 3
# Train Loss: 5.56
# Accuracy: 55.47%
#
# Epoch 6, Iteration 4
# Train Loss: 5.24
# Accuracy: 56.25%
#
# Epoch 6, Iteration 5
# Train Loss: 5.38
# Accuracy: 56.25%
#
# Epoch 6, Iteration 6
# Train Loss: 5.78
# Accuracy: 47.66%
#
# Epoch 6, Iteration 7
# Train Loss: 5.98
# Accuracy: 46.88%
#
# Epoch 6, Iteration 8
# Train Loss: 5.22
# Accuracy: 54.69%
#
# Epoch 6, Iteration 9
# Train Loss: 5.61
# Accuracy: 50.78%
#
# Epoch 6, Iteration 10
# Train Loss: 5.55
# Accuracy: 60.66%
#
# 0.2899305555555555
# Accuracy: 28.99%
#
# Epoch 7, Iteration 0
# Train Loss: 5.79
# Accuracy: 47.66%
#
# Epoch 7, Iteration 1
# Train Loss: 5.30
# Accuracy: 57.81%
#
# Epoch 7, Iteration 2
# Train Loss: 5.41
# Accuracy: 53.12%
#
# Epoch 7, Iteration 3
# Train Loss: 5.31
# Accuracy: 57.03%
#
# Epoch 7, Iteration 4
# Train Loss: 5.30
# Accuracy: 55.47%
#
# Epoch 7, Iteration 5
# Train Loss: 5.62
# Accuracy: 53.12%
#
# Epoch 7, Iteration 6
# Train Loss: 5.60
# Accuracy: 51.56%
#
# Epoch 7, Iteration 7
# Train Loss: 5.79
# Accuracy: 57.03%
#
# Epoch 7, Iteration 8
# Train Loss: 5.34
# Accuracy: 53.12%
#
# Epoch 7, Iteration 9
# Train Loss: 5.40
# Accuracy: 58.59%
#
# Epoch 7, Iteration 10
# Train Loss: 6.25
# Accuracy: 40.98%
#
# 0.24817708333333333
# Accuracy: 24.82%
#
# Epoch 8, Iteration 0
# Train Loss: 5.70
# Accuracy: 48.44%
#
# Epoch 8, Iteration 1
# Train Loss: 5.44
# Accuracy: 56.25%
#
# Epoch 8, Iteration 2
# Train Loss: 5.64
# Accuracy: 53.91%
#
# Epoch 8, Iteration 3
# Train Loss: 5.50
# Accuracy: 52.34%
#
# Epoch 8, Iteration 4
# Train Loss: 5.55
# Accuracy: 53.12%
#
# Epoch 8, Iteration 5
# Train Loss: 5.68
# Accuracy: 54.69%
#
# Epoch 8, Iteration 6
# Train Loss: 5.29
# Accuracy: 60.94%
#
# Epoch 8, Iteration 7
# Train Loss: 5.10
# Accuracy: 58.59%
#
# Epoch 8, Iteration 8
# Train Loss: 6.12
# Accuracy: 45.31%
#
# Epoch 8, Iteration 9
# Train Loss: 6.03
# Accuracy: 47.66%
#
# Epoch 8, Iteration 10
# Train Loss: 5.43
# Accuracy: 55.74%
#
# 0.2576388888888889
# Accuracy: 25.76%
#
# Epoch 9, Iteration 0
# Train Loss: 5.43
# Accuracy: 58.59%
#
# Epoch 9, Iteration 1
# Train Loss: 5.46
# Accuracy: 54.69%
#
# Epoch 9, Iteration 2
# Train Loss: 5.36
# Accuracy: 54.69%
#
# Epoch 9, Iteration 3
# Train Loss: 5.87
# Accuracy: 47.66%
#
# Epoch 9, Iteration 4
# Train Loss: 5.59
# Accuracy: 53.91%
#
# Epoch 9, Iteration 5
# Train Loss: 5.06
# Accuracy: 61.72%
#
# Epoch 9, Iteration 6
# Train Loss: 5.57
# Accuracy: 51.56%
#
# Epoch 9, Iteration 7
# Train Loss: 5.32
# Accuracy: 57.81%
#
# Epoch 9, Iteration 8
# Train Loss: 5.32
# Accuracy: 51.56%
#
# Epoch 9, Iteration 9
# Train Loss: 5.29
# Accuracy: 56.25%
#
# Epoch 9, Iteration 10
# Train Loss: 5.68
# Accuracy: 54.10%
#
# 0.24947916666666667
# Accuracy: 24.95%
#
# Epoch 10, Iteration 0
# Train Loss: 5.54
# Accuracy: 56.25%
#
# Epoch 10, Iteration 1
# Train Loss: 5.22
# Accuracy: 57.81%
#
# Epoch 10, Iteration 2
# Train Loss: 5.16
# Accuracy: 54.69%
#
# Epoch 10, Iteration 3
# Train Loss: 5.20
# Accuracy: 56.25%
#
# Epoch 10, Iteration 4
# Train Loss: 5.47
# Accuracy: 57.81%
#
# Epoch 10, Iteration 5
# Train Loss: 5.56
# Accuracy: 57.03%
#
# Epoch 10, Iteration 6
# Train Loss: 5.54
# Accuracy: 55.47%
#
# Epoch 10, Iteration 7
# Train Loss: 5.20
# Accuracy: 59.38%
#
# Epoch 10, Iteration 8
# Train Loss: 5.61
# Accuracy: 52.34%
#
# Epoch 10, Iteration 9
# Train Loss: 5.49
# Accuracy: 53.12%
#
# Epoch 10, Iteration 10
# Train Loss: 5.89
# Accuracy: 52.46%
#
# 0.27395833333333336
# Accuracy: 27.40%
#
# Epoch 11, Iteration 0
# Train Loss: 5.31
# Accuracy: 62.50%
#
# Epoch 11, Iteration 1
# Train Loss: 4.99
# Accuracy: 53.91%
#
# Epoch 11, Iteration 2
# Train Loss: 5.24
# Accuracy: 57.03%
#
# Epoch 11, Iteration 3
# Train Loss: 5.64
# Accuracy: 53.12%
#
# Epoch 11, Iteration 4
# Train Loss: 5.60
# Accuracy: 50.00%
#
# Epoch 11, Iteration 5
# Train Loss: 5.33
# Accuracy: 54.69%
#
# Epoch 11, Iteration 6
# Train Loss: 5.49
# Accuracy: 49.22%
#
# Epoch 11, Iteration 7
# Train Loss: 5.41
# Accuracy: 57.03%
#
# Epoch 11, Iteration 8
# Train Loss: 5.71
# Accuracy: 50.00%
#
# Epoch 11, Iteration 9
# Train Loss: 5.10
# Accuracy: 67.19%
#
# Epoch 11, Iteration 10
# Train Loss: 5.90
# Accuracy: 54.10%
#
# 0.26588541666666665
# Accuracy: 26.59%
#
# Epoch 12, Iteration 0
# Train Loss: 5.75
# Accuracy: 48.44%
#
# Epoch 12, Iteration 1
# Train Loss: 5.95
# Accuracy: 43.75%
#
# Epoch 12, Iteration 2
# Train Loss: 5.64
# Accuracy: 49.22%
#
# Epoch 12, Iteration 3
# Train Loss: 5.28
# Accuracy: 57.81%
#
# Epoch 12, Iteration 4
# Train Loss: 5.87
# Accuracy: 46.09%
#
# Epoch 12, Iteration 5
# Train Loss: 5.02
# Accuracy: 60.94%
#
# Epoch 12, Iteration 6
# Train Loss: 5.44
# Accuracy: 50.00%
#
# Epoch 12, Iteration 7
# Train Loss: 5.06
# Accuracy: 63.28%
#
# Epoch 12, Iteration 8
# Train Loss: 5.81
# Accuracy: 50.00%
#
# Epoch 12, Iteration 9
# Train Loss: 5.32
# Accuracy: 57.81%
#
# Epoch 12, Iteration 10
# Train Loss: 5.10
# Accuracy: 54.10%
#
# 0.25668402777777777
# Accuracy: 25.67%
#
# Epoch 13, Iteration 0
# Train Loss: 5.54
# Accuracy: 51.56%
#
# Epoch 13, Iteration 1
# Train Loss: 5.66
# Accuracy: 49.22%
#
# Epoch 13, Iteration 2
# Train Loss: 5.33
# Accuracy: 53.12%
#
# Epoch 13, Iteration 3
# Train Loss: 5.41
# Accuracy: 54.69%
#
# Epoch 13, Iteration 4
# Train Loss: 5.30
# Accuracy: 58.59%
#
# Epoch 13, Iteration 5
# Train Loss: 5.55
# Accuracy: 50.78%
#
# Epoch 13, Iteration 6
# Train Loss: 5.04
# Accuracy: 64.06%
#
# Epoch 13, Iteration 7
# Train Loss: 5.45
# Accuracy: 53.91%
#
# Epoch 13, Iteration 8
# Train Loss: 5.29
# Accuracy: 58.59%
#
# Epoch 13, Iteration 9
# Train Loss: 5.01
# Accuracy: 62.50%
#
# Epoch 13, Iteration 10
# Train Loss: 5.40
# Accuracy: 57.38%
#
# 0.2730034722222222
# Accuracy: 27.30%
#
# Epoch 14, Iteration 0
# Train Loss: 5.19
# Accuracy: 57.03%
#
# Epoch 14, Iteration 1
# Train Loss: 4.96
# Accuracy: 59.38%
#
# Epoch 14, Iteration 2
# Train Loss: 5.27
# Accuracy: 60.16%
#
# Epoch 14, Iteration 3
# Train Loss: 5.17
# Accuracy: 56.25%
#
# Epoch 14, Iteration 4
# Train Loss: 5.42
# Accuracy: 53.91%
#
# Epoch 14, Iteration 5
# Train Loss: 5.53
# Accuracy: 52.34%
#
# Epoch 14, Iteration 6
# Train Loss: 5.25
# Accuracy: 57.03%
#
# Epoch 14, Iteration 7
# Train Loss: 5.61
# Accuracy: 53.12%
#
# Epoch 14, Iteration 8
# Train Loss: 4.96
# Accuracy: 64.84%
#
# Epoch 14, Iteration 9
# Train Loss: 5.16
# Accuracy: 59.38%
#
# Epoch 14, Iteration 10
# Train Loss: 5.34
# Accuracy: 59.02%
#
# 0.27196180555555555
# Accuracy: 27.20%
#
# Epoch 15, Iteration 0
# Train Loss: 4.54
# Accuracy: 66.41%
#
# Epoch 15, Iteration 1
# Train Loss: 5.47
# Accuracy: 57.03%
#
# Epoch 15, Iteration 2
# Train Loss: 5.26
# Accuracy: 58.59%
#
# Epoch 15, Iteration 3
# Train Loss: 5.56
# Accuracy: 55.47%
#
# Epoch 15, Iteration 4
# Train Loss: 4.82
# Accuracy: 60.16%
#
# Epoch 15, Iteration 5
# Train Loss: 5.43
# Accuracy: 51.56%
#
# Epoch 15, Iteration 6
# Train Loss: 5.17
# Accuracy: 58.59%
#
# Epoch 15, Iteration 7
# Train Loss: 5.36
# Accuracy: 57.03%
#
# Epoch 15, Iteration 8
# Train Loss: 5.76
# Accuracy: 54.69%
#
# Epoch 15, Iteration 9
# Train Loss: 5.23
# Accuracy: 61.72%
#
# Epoch 15, Iteration 10
# Train Loss: 5.33
# Accuracy: 59.02%
#
# 0.2537326388888889
# Accuracy: 25.37%
#
# Epoch 16, Iteration 0
# Train Loss: 5.01
# Accuracy: 64.84%
#
# Epoch 16, Iteration 1
# Train Loss: 5.58
# Accuracy: 57.03%
#
# Epoch 16, Iteration 2
# Train Loss: 5.39
# Accuracy: 52.34%
#
# Epoch 16, Iteration 3
# Train Loss: 4.80
# Accuracy: 60.16%
#
# Epoch 16, Iteration 4
# Train Loss: 5.07
# Accuracy: 57.81%
#
# Epoch 16, Iteration 5
# Train Loss: 5.69
# Accuracy: 45.31%
#
# Epoch 16, Iteration 6
# Train Loss: 5.30
# Accuracy: 53.91%
#
# Epoch 16, Iteration 7
# Train Loss: 4.91
# Accuracy: 65.62%
#
# Epoch 16, Iteration 8
# Train Loss: 5.20
# Accuracy: 57.81%
#
# Epoch 16, Iteration 9
# Train Loss: 6.05
# Accuracy: 47.66%
#
# Epoch 16, Iteration 10
# Train Loss: 5.14
# Accuracy: 62.30%
#
# 0.2674479166666667
# Accuracy: 26.74%
#
# Epoch 17, Iteration 0
# Train Loss: 4.93
# Accuracy: 61.72%
#
# Epoch 17, Iteration 1
# Train Loss: 4.90
# Accuracy: 61.72%
#
# Epoch 17, Iteration 2
# Train Loss: 5.49
# Accuracy: 53.91%
#
# Epoch 17, Iteration 3
# Train Loss: 5.01
# Accuracy: 55.47%
#
# Epoch 17, Iteration 4
# Train Loss: 5.06
# Accuracy: 61.72%
#
# Epoch 17, Iteration 5
# Train Loss: 5.54
# Accuracy: 53.91%
#
# Epoch 17, Iteration 6
# Train Loss: 5.29
# Accuracy: 54.69%
#
# Epoch 17, Iteration 7
# Train Loss: 5.22
# Accuracy: 57.81%
#
# Epoch 17, Iteration 8
# Train Loss: 4.85
# Accuracy: 60.94%
#
# Epoch 17, Iteration 9
# Train Loss: 5.17
# Accuracy: 60.94%
#
# Epoch 17, Iteration 10
# Train Loss: 5.62
# Accuracy: 45.90%
#
# 0.27621527777777777
# Accuracy: 27.62%
#
# Epoch 18, Iteration 0
# Train Loss: 5.14
# Accuracy: 58.59%
#
# Epoch 18, Iteration 1
# Train Loss: 5.40
# Accuracy: 60.16%
#
# Epoch 18, Iteration 2
# Train Loss: 5.35
# Accuracy: 55.47%
#
# Epoch 18, Iteration 3
# Train Loss: 5.24
# Accuracy: 57.03%
#
# Epoch 18, Iteration 4
# Train Loss: 5.27
# Accuracy: 57.03%
#
# Epoch 18, Iteration 5
# Train Loss: 5.13
# Accuracy: 54.69%
#
# Epoch 18, Iteration 6
# Train Loss: 5.23
# Accuracy: 57.03%
#
# Epoch 18, Iteration 7
# Train Loss: 4.96
# Accuracy: 57.81%
#
# Epoch 18, Iteration 8
# Train Loss: 4.66
# Accuracy: 64.06%
#
# Epoch 18, Iteration 9
# Train Loss: 5.01
# Accuracy: 60.16%
#
# Epoch 18, Iteration 10
# Train Loss: 5.30
# Accuracy: 60.66%
#
# 0.2530381944444445
# Accuracy: 25.30%
#
# Epoch 19, Iteration 0
# Train Loss: 4.96
# Accuracy: 61.72%
#
# Epoch 19, Iteration 1
# Train Loss: 5.43
# Accuracy: 53.91%
#
# Epoch 19, Iteration 2
# Train Loss: 4.88
# Accuracy: 61.72%
#
# Epoch 19, Iteration 3
# Train Loss: 4.88
# Accuracy: 60.16%
#
# Epoch 19, Iteration 4
# Train Loss: 4.59
# Accuracy: 61.72%
#
# Epoch 19, Iteration 5
# Train Loss: 5.52
# Accuracy: 54.69%
#
# Epoch 19, Iteration 6
# Train Loss: 5.01
# Accuracy: 64.06%
#
# Epoch 19, Iteration 7
# Train Loss: 5.02
# Accuracy: 53.12%
#
# Epoch 19, Iteration 8
# Train Loss: 5.19
# Accuracy: 64.06%
#
# Epoch 19, Iteration 9
# Train Loss: 5.32
# Accuracy: 56.25%
#
# Epoch 19, Iteration 10
# Train Loss: 4.92
# Accuracy: 62.30%
#
# 0.24427083333333333
# Accuracy: 24.43%
#
# Epoch 20, Iteration 0
# Train Loss: 5.09
# Accuracy: 58.59%
#
# Epoch 20, Iteration 1
# Train Loss: 5.08
# Accuracy: 63.28%
#
# Epoch 20, Iteration 2
# Train Loss: 5.12
# Accuracy: 58.59%
#
# Epoch 20, Iteration 3
# Train Loss: 4.98
# Accuracy: 59.38%
#
# Epoch 20, Iteration 4
# Train Loss: 5.05
# Accuracy: 63.28%
#
# Epoch 20, Iteration 5
# Train Loss: 4.98
# Accuracy: 63.28%
#
# Epoch 20, Iteration 6
# Train Loss: 5.27
# Accuracy: 58.59%
#
# Epoch 20, Iteration 7
# Train Loss: 4.90
# Accuracy: 57.81%
#
# Epoch 20, Iteration 8
# Train Loss: 4.77
# Accuracy: 64.06%
#
# Epoch 20, Iteration 9
# Train Loss: 4.60
# Accuracy: 67.97%
#
# Epoch 20, Iteration 10
# Train Loss: 5.04
# Accuracy: 62.30%
#
# 0.2569444444444445
# Accuracy: 25.69%
#
# Epoch 21, Iteration 0
# Train Loss: 5.20
# Accuracy: 59.38%
#
# Epoch 21, Iteration 1
# Train Loss: 4.96
# Accuracy: 62.50%
#
# Epoch 21, Iteration 2
# Train Loss: 4.79
# Accuracy: 64.84%
#
# Epoch 21, Iteration 3
# Train Loss: 5.40
# Accuracy: 56.25%
#
# Epoch 21, Iteration 4
# Train Loss: 4.92
# Accuracy: 67.19%
#
# Epoch 21, Iteration 5
# Train Loss: 4.91
# Accuracy: 60.94%
#
# Epoch 21, Iteration 6
# Train Loss: 4.86
# Accuracy: 62.50%
#
# Epoch 21, Iteration 7
# Train Loss: 5.08
# Accuracy: 62.50%
#
# Epoch 21, Iteration 8
# Train Loss: 5.00
# Accuracy: 66.41%
#
# Epoch 21, Iteration 9
# Train Loss: 4.97
# Accuracy: 57.03%
#
# Epoch 21, Iteration 10
# Train Loss: 4.55
# Accuracy: 75.41%
#
# 0.22994791666666667
# Accuracy: 22.99%
#
# Epoch 22, Iteration 0
# Train Loss: 5.61
# Accuracy: 53.91%
#
# Epoch 22, Iteration 1
# Train Loss: 5.40
# Accuracy: 58.59%
#
# Epoch 22, Iteration 2
# Train Loss: 4.53
# Accuracy: 69.53%
#
# Epoch 22, Iteration 3
# Train Loss: 4.50
# Accuracy: 67.19%
#
# Epoch 22, Iteration 4
# Train Loss: 4.94
# Accuracy: 61.72%
#
# Epoch 22, Iteration 5
# Train Loss: 4.94
# Accuracy: 64.06%
#
# Epoch 22, Iteration 6
# Train Loss: 5.01
# Accuracy: 57.81%
#
# Epoch 22, Iteration 7
# Train Loss: 4.64
# Accuracy: 60.94%
#
# Epoch 22, Iteration 8
# Train Loss: 5.24
# Accuracy: 63.28%
#
# Epoch 22, Iteration 9
# Train Loss: 4.93
# Accuracy: 61.72%
#
# Epoch 22, Iteration 10
# Train Loss: 4.73
# Accuracy: 70.49%
#
# 0.2756076388888889
# Accuracy: 27.56%
#
# Epoch 23, Iteration 0
# Train Loss: 4.64
# Accuracy: 68.75%
#
# Epoch 23, Iteration 1
# Train Loss: 4.72
# Accuracy: 68.75%
#
# Epoch 23, Iteration 2
# Train Loss: 4.57
# Accuracy: 67.97%
#
# Epoch 23, Iteration 3
# Train Loss: 4.94
# Accuracy: 56.25%
#
# Epoch 23, Iteration 4
# Train Loss: 5.20
# Accuracy: 55.47%
#
# Epoch 23, Iteration 5
# Train Loss: 5.03
# Accuracy: 59.38%
#
# Epoch 23, Iteration 6
# Train Loss: 5.02
# Accuracy: 57.03%
#
# Epoch 23, Iteration 7
# Train Loss: 5.07
# Accuracy: 59.38%
#
# Epoch 23, Iteration 8
# Train Loss: 4.51
# Accuracy: 67.97%
#
# Epoch 23, Iteration 9
# Train Loss: 4.75
# Accuracy: 64.06%
#
# Epoch 23, Iteration 10
# Train Loss: 4.59
# Accuracy: 70.49%
#
# 0.2530381944444445
# Accuracy: 25.30%
#
# Epoch 24, Iteration 0
# Train Loss: 5.11
# Accuracy: 63.28%
#
# Epoch 24, Iteration 1
# Train Loss: 5.14
# Accuracy: 57.81%
#
# Epoch 24, Iteration 2
# Train Loss: 5.08
# Accuracy: 57.81%
#
# Epoch 24, Iteration 3
# Train Loss: 4.56
# Accuracy: 67.19%
#
# Epoch 24, Iteration 4
# Train Loss: 4.51
# Accuracy: 68.75%
#
# Epoch 24, Iteration 5
# Train Loss: 4.40
# Accuracy: 69.53%
#
# Epoch 24, Iteration 6
# Train Loss: 4.75
# Accuracy: 63.28%
#
# Epoch 24, Iteration 7
# Train Loss: 4.36
# Accuracy: 70.31%
#
# Epoch 24, Iteration 8
# Train Loss: 4.72
# Accuracy: 66.41%
#
# Epoch 24, Iteration 9
# Train Loss: 5.36
# Accuracy: 58.59%
#
# Epoch 24, Iteration 10
# Train Loss: 4.91
# Accuracy: 60.66%
#
# 0.2596354166666667
# Accuracy: 25.96%
#
# Epoch 25, Iteration 0
# Train Loss: 4.82
# Accuracy: 65.62%
#
# Epoch 25, Iteration 1
# Train Loss: 4.61
# Accuracy: 68.75%
#
# Epoch 25, Iteration 2
# Train Loss: 5.12
# Accuracy: 60.16%
#
# Epoch 25, Iteration 3
# Train Loss: 4.74
# Accuracy: 60.16%
#
# Epoch 25, Iteration 4
# Train Loss: 5.24
# Accuracy: 64.84%
#
# Epoch 25, Iteration 5
# Train Loss: 5.41
# Accuracy: 56.25%
#
# Epoch 25, Iteration 6
# Train Loss: 4.87
# Accuracy: 64.06%
#
# Epoch 25, Iteration 7
# Train Loss: 4.59
# Accuracy: 64.84%
#
# Epoch 25, Iteration 8
# Train Loss: 4.77
# Accuracy: 64.06%
#
# Epoch 25, Iteration 9
# Train Loss: 4.75
# Accuracy: 67.97%
#
# Epoch 25, Iteration 10
# Train Loss: 4.13
# Accuracy: 77.05%
#
# 0.23220486111111113
# Accuracy: 23.22%
#
# Epoch 26, Iteration 0
# Train Loss: 4.75
# Accuracy: 62.50%
#
# Epoch 26, Iteration 1
# Train Loss: 5.16
# Accuracy: 56.25%
#
# Epoch 26, Iteration 2
# Train Loss: 4.64
# Accuracy: 63.28%
#
# Epoch 26, Iteration 3
# Train Loss: 4.55
# Accuracy: 69.53%
#
# Epoch 26, Iteration 4
# Train Loss: 4.20
# Accuracy: 71.88%
#
# Epoch 26, Iteration 5
# Train Loss: 4.73
# Accuracy: 62.50%
#
# Epoch 26, Iteration 6
# Train Loss: 4.70
# Accuracy: 63.28%
#
# Epoch 26, Iteration 7
# Train Loss: 4.95
# Accuracy: 60.94%
#
# Epoch 26, Iteration 8
# Train Loss: 4.64
# Accuracy: 67.97%
#
# Epoch 26, Iteration 9
# Train Loss: 4.77
# Accuracy: 64.84%
#
# Epoch 26, Iteration 10
# Train Loss: 4.58
# Accuracy: 65.57%
#
# 0.26710069444444445
# Accuracy: 26.71%
#
# Epoch 27, Iteration 0
# Train Loss: 4.96
# Accuracy: 64.84%
#
# Epoch 27, Iteration 1
# Train Loss: 4.61
# Accuracy: 63.28%
#
# Epoch 27, Iteration 2
# Train Loss: 5.18
# Accuracy: 56.25%
#
# Epoch 27, Iteration 3
# Train Loss: 4.45
# Accuracy: 67.19%
#
# Epoch 27, Iteration 4
# Train Loss: 4.84
# Accuracy: 59.38%
#
# Epoch 27, Iteration 5
# Train Loss: 4.59
# Accuracy: 67.19%
#
# Epoch 27, Iteration 6
# Train Loss: 4.46
# Accuracy: 69.53%
#
# Epoch 27, Iteration 7
# Train Loss: 4.73
# Accuracy: 67.19%
#
# Epoch 27, Iteration 8
# Train Loss: 4.55
# Accuracy: 67.97%
#
# Epoch 27, Iteration 9
# Train Loss: 5.16
# Accuracy: 64.84%
#
# Epoch 27, Iteration 10
# Train Loss: 4.66
# Accuracy: 67.21%
#
# 0.24817708333333333
# Accuracy: 24.82%
#
# Epoch 28, Iteration 0
# Train Loss: 4.59
# Accuracy: 62.50%
#
# Epoch 28, Iteration 1
# Train Loss: 5.20
# Accuracy: 55.47%
#
# Epoch 28, Iteration 2
# Train Loss: 5.05
# Accuracy: 57.03%
#
# Epoch 28, Iteration 3
# Train Loss: 4.72
# Accuracy: 63.28%
#
# Epoch 28, Iteration 4
# Train Loss: 4.62
# Accuracy: 66.41%
#
# Epoch 28, Iteration 5
# Train Loss: 4.62
# Accuracy: 62.50%
#
# Epoch 28, Iteration 6
# Train Loss: 4.85
# Accuracy: 60.16%
#
# Epoch 28, Iteration 7
# Train Loss: 4.65
# Accuracy: 64.84%
#
# Epoch 28, Iteration 8
# Train Loss: 4.38
# Accuracy: 70.31%
#
# Epoch 28, Iteration 9
# Train Loss: 4.27
# Accuracy: 73.44%
#
# Epoch 28, Iteration 10
# Train Loss: 4.11
# Accuracy: 75.41%
#
# 0.2423611111111111
# Accuracy: 24.24%
#
# Epoch 29, Iteration 0
# Train Loss: 5.00
# Accuracy: 62.50%
#
# Epoch 29, Iteration 1
# Train Loss: 4.78
# Accuracy: 60.94%
#
# Epoch 29, Iteration 2
# Train Loss: 4.25
# Accuracy: 70.31%
#
# Epoch 29, Iteration 3
# Train Loss: 4.36
# Accuracy: 72.66%
#
# Epoch 29, Iteration 4
# Train Loss: 4.24
# Accuracy: 72.66%
#
# Epoch 29, Iteration 5
# Train Loss: 4.67
# Accuracy: 69.53%
#
# Epoch 29, Iteration 6
# Train Loss: 4.49
# Accuracy: 70.31%
#
# Epoch 29, Iteration 7
# Train Loss: 5.26
# Accuracy: 60.16%
#
# Epoch 29, Iteration 8
# Train Loss: 4.61
# Accuracy: 62.50%
#
# Epoch 29, Iteration 9
# Train Loss: 4.30
# Accuracy: 68.75%
#
# Epoch 29, Iteration 10
# Train Loss: 5.23
# Accuracy: 52.46%
#
# 0.2236979166666667
# Accuracy: 22.37%
#
# Epoch 30, Iteration 0
# Train Loss: 4.34
# Accuracy: 69.53%
#
# Epoch 30, Iteration 1
# Train Loss: 4.44
# Accuracy: 67.19%
#
# Epoch 30, Iteration 2
# Train Loss: 4.94
# Accuracy: 64.84%
#
# Epoch 30, Iteration 3
# Train Loss: 4.80
# Accuracy: 64.84%
#
# Epoch 30, Iteration 4
# Train Loss: 4.21
# Accuracy: 71.09%
#
# Epoch 30, Iteration 5
# Train Loss: 4.69
# Accuracy: 64.06%
#
# Epoch 30, Iteration 6
# Train Loss: 4.44
# Accuracy: 69.53%
#
# Epoch 30, Iteration 7
# Train Loss: 4.53
# Accuracy: 63.28%
#
# Epoch 30, Iteration 8
# Train Loss: 4.94
# Accuracy: 61.72%
#
# Epoch 30, Iteration 9
# Train Loss: 4.02
# Accuracy: 72.66%
#
# Epoch 30, Iteration 10
# Train Loss: 4.56
# Accuracy: 60.66%
#
# 0.27335069444444443
# Accuracy: 27.34%
#
# Epoch 31, Iteration 0
# Train Loss: 4.21
# Accuracy: 72.66%
#
# Epoch 31, Iteration 1
# Train Loss: 4.48
# Accuracy: 68.75%
#
# Epoch 31, Iteration 2
# Train Loss: 4.49
# Accuracy: 67.97%
#
# Epoch 31, Iteration 3
# Train Loss: 4.60
# Accuracy: 66.41%
#
# Accuracy: 64.06%
#
# Epoch 37, Iteration 9
# Train Loss: 4.33
# Accuracy: 66.41%
#
# Epoch 37, Iteration 10
# Train Loss: 4.57
# Accuracy: 65.57%
#
# 0.23185763888888888
# Accuracy: 23.19%
#
# Epoch 38, Iteration 0
# Train Loss: 4.52
# Accuracy: 68.75%
#
# Epoch 38, Iteration 1
# Train Loss: 4.37
# Accuracy: 69.53%
#
# Epoch 38, Iteration 2
# Train Loss: 4.78
# Accuracy: 59.38%
#
# Epoch 38, Iteration 3
# Train Loss: 4.57
# Accuracy: 68.75%
#
# Epoch 38, Iteration 4
# Train Loss: 4.36
# Accuracy: 69.53%
#
# Epoch 38, Iteration 5
# Train Loss: 4.78
# Accuracy: 63.28%
#
# Epoch 38, Iteration 6
# Train Loss: 4.42
# Accuracy: 67.97%
#
# Epoch 38, Iteration 7
# Train Loss: 4.59
# Accuracy: 69.53%
#
# Epoch 38, Iteration 8
# Train Loss: 4.11
# Accuracy: 72.66%
#
# Epoch 38, Iteration 9
# Train Loss: 4.53
# Accuracy: 71.09%
#
# Epoch 38, Iteration 10
# Train Loss: 4.66
# Accuracy: 63.93%
#
# 0.2609375
# Accuracy: 26.09%
#
# Epoch 39, Iteration 0
# Train Loss: 4.57
# Accuracy: 60.16%
#
# Epoch 39, Iteration 1
# Train Loss: 4.72
# Accuracy: 64.84%
#
# Epoch 39, Iteration 2
# Train Loss: 4.09
# Accuracy: 74.22%
#
# Epoch 39, Iteration 3
# Train Loss: 4.42
# Accuracy: 71.09%
#
# Epoch 39, Iteration 4
# Train Loss: 4.13
# Accuracy: 72.66%
#
# Epoch 39, Iteration 5
# Train Loss: 4.20
# Accuracy: 71.88%
#
# Epoch 39, Iteration 6
# Train Loss: 4.13
# Accuracy: 73.44%
#
# Epoch 39, Iteration 7
# Train Loss: 4.29
# Accuracy: 71.88%
#
# Epoch 39, Iteration 8
# Train Loss: 4.51
# Accuracy: 65.62%
#
# Epoch 39, Iteration 9
# Train Loss: 4.12
# Accuracy: 72.66%
#
# Epoch 39, Iteration 10
# Train Loss: 3.72
# Accuracy: 73.77%
#
# 0.24296874999999998
# Accuracy: 24.30%
#
# Epoch 40, Iteration 0
# Train Loss: 4.61
# Accuracy: 68.75%
#
# Epoch 40, Iteration 1
# Train Loss: 4.07
# Accuracy: 77.34%
#
# Epoch 40, Iteration 2
# Train Loss: 4.45
# Accuracy: 70.31%
#
# Epoch 40, Iteration 3
# Train Loss: 4.07
# Accuracy: 72.66%
#
# Epoch 40, Iteration 4
# Train Loss: 3.96
# Accuracy: 71.88%
#
# Epoch 40, Iteration 5
# Train Loss: 4.56
# Accuracy: 64.06%
#
# Epoch 40, Iteration 6
# Train Loss: 4.21
# Accuracy: 75.00%
#
# Epoch 40, Iteration 7
# Train Loss: 4.06
# Accuracy: 71.88%
#
# Epoch 40, Iteration 8
# Train Loss: 4.66
# Accuracy: 63.28%
#
# Epoch 40, Iteration 9
# Train Loss: 4.13
# Accuracy: 69.53%
#
# Epoch 40, Iteration 10
# Train Loss: 4.17
# Accuracy: 73.77%
# Train Loss: 4.45
# Accuracy: 70.31%
#
# Epoch 63, Iteration 4
# Train Loss: 4.38
# Accuracy: 71.88%
#
# Epoch 63, Iteration 5
# Train Loss: 4.12
# Accuracy: 71.09%
#
# Epoch 63, Iteration 6
# Train Loss: 4.16
# Accuracy: 67.97%
#
# Epoch 63, Iteration 7
# Train Loss: 4.15
# Accuracy: 74.22%
#
# Epoch 63, Iteration 8
# Train Loss: 4.98
# Accuracy: 60.16%
#
# Epoch 63, Iteration 9
# Train Loss: 4.60
# Accuracy: 64.06%
#
# Epoch 63, Iteration 10
# Train Loss: 4.12
# Accuracy: 72.13%
#
# 0.24557291666666667
# Accuracy: 24.56%
#
# Epoch 64, Iteration 0
# Train Loss: 4.49
# Accuracy: 61.72%
#
# Epoch 64, Iteration 1
# Train Loss: 3.76
# Accuracy: 80.47%
#
# Epoch 64, Iteration 2
# Train Loss: 4.71
# Accuracy: 64.84%
#
# Epoch 64, Iteration 3
# Train Loss: 4.25
# Accuracy: 72.66%
#
# Epoch 64, Iteration 4
# Train Loss: 3.71
# Accuracy: 76.56%
#
# Epoch 64, Iteration 5
# Train Loss: 4.15
# Accuracy: 71.09%
#
# Epoch 64, Iteration 6
# Train Loss: 4.54
# Accuracy: 74.22%
#
# Epoch 64, Iteration 7
# Train Loss: 4.15
# Accuracy: 71.88%
#
# Epoch 64, Iteration 8
# Train Loss: 4.15
# Accuracy: 70.31%
#
# Epoch 64, Iteration 9
# Train Loss: 3.71
# Accuracy: 76.56%
#
# Epoch 64, Iteration 10
# Train Loss: 4.38
# Accuracy: 75.41%
#
# 0.24105902777777777
# Accuracy: 24.11%
#
# Epoch 65, Iteration 0
# Train Loss: 3.60
# Accuracy: 82.81%
#
# Epoch 65, Iteration 1
# Train Loss: 3.29
# Accuracy: 83.59%
#
# Epoch 65, Iteration 2
# Train Loss: 3.72
# Accuracy: 74.22%
#
# Epoch 65, Iteration 3
# Train Loss: 4.26
# Accuracy: 71.88%
#
# Epoch 65, Iteration 4
# Train Loss: 3.89
# Accuracy: 71.88%
#
# Epoch 65, Iteration 5
# Train Loss: 3.71
# Accuracy: 75.78%
#
# Epoch 65, Iteration 6
# Train Loss: 4.06
# Accuracy: 75.78%
#
# Epoch 65, Iteration 7
# Train Loss: 4.38
# Accuracy: 69.53%
#
# Epoch 65, Iteration 8
# Train Loss: 4.19
# Accuracy: 74.22%
#
# Epoch 65, Iteration 9
# Train Loss: 3.71
# Accuracy: 75.78%
#
# Epoch 65, Iteration 10
# Train Loss: 3.74
# Accuracy: 78.69%
#
# 0.23515624999999998
# Accuracy: 23.52%
#
# Epoch 66, Iteration 0
# Train Loss: 3.63
# Accuracy: 80.47%
#
# Epoch 66, Iteration 1
# Train Loss: 3.72
# Accuracy: 76.56%
#
# Epoch 66, Iteration 2
# Train Loss: 3.57
# Accuracy: 79.69%
#
# Epoch 66, Iteration 3
# Train Loss: 3.80
# Accuracy: 75.78%
#
# Epoch 66, Iteration 4
# Train Loss: 3.97
# Accuracy: 76.56%
#
# Epoch 66, Iteration 5
# Train Loss: 4.15
# Accuracy: 70.31%
#
# Epoch 66, Iteration 6
# Train Loss: 3.84
# Accuracy: 74.22%
#
# Epoch 66, Iteration 7
# Train Loss: 3.53
# Accuracy: 81.25%
#
# Epoch 66, Iteration 8
# Train Loss: 3.76
# Accuracy: 78.91%
#
# Epoch 66, Iteration 9
# Train Loss: 4.00
# Accuracy: 73.44%
#
# Epoch 66, Iteration 10
# Train Loss: 3.76
# Accuracy: 73.77%
#
# 0.22048611111111113
# Accuracy: 22.05%
#
# Epoch 67, Iteration 0
# Train Loss: 3.61
# Accuracy: 77.34%
#
# Epoch 67, Iteration 1
# Train Loss: 3.97
# Accuracy: 73.44%
#
# Epoch 67, Iteration 2
# Train Loss: 3.71
# Accuracy: 78.91%
#
# Epoch 67, Iteration 3
# Train Loss: 3.57
# Accuracy: 77.34%
#
# Epoch 67, Iteration 4
# Train Loss: 3.74
# Accuracy: 75.78%
#
# Epoch 67, Iteration 5
# Train Loss: 3.78
# Accuracy: 74.22%
#
# Epoch 67, Iteration 6
# Train Loss: 3.88
# Accuracy: 75.00%
#
# Epoch 67, Iteration 7
# Train Loss: 4.03
# Accuracy: 75.00%
#
# Epoch 67, Iteration 8
# Train Loss: 4.01
# Accuracy: 72.66%
#
# Epoch 67, Iteration 9
# Train Loss: 3.68
# Accuracy: 78.12%
#
# Epoch 67, Iteration 10
# Train Loss: 3.13
# Accuracy: 81.97%
#
# 0.2462673611111111
# Accuracy: 24.63%
#
# Epoch 68, Iteration 0
# Train Loss: 4.09
# Accuracy: 69.53%
#
# Epoch 68, Iteration 1
# Train Loss: 3.59
# Accuracy: 81.25%
#
# Epoch 68, Iteration 2
# Train Loss: 3.79
# Accuracy: 76.56%
#
# Epoch 68, Iteration 3
# Train Loss: 3.97
# Accuracy: 74.22%
#
# Epoch 68, Iteration 4
# Train Loss: 3.81
# Accuracy: 72.66%
#
# Epoch 68, Iteration 5
# Train Loss: 3.83
# Accuracy: 77.34%
#
# Epoch 68, Iteration 6
# Train Loss: 3.64
# Accuracy: 80.47%
#
# Epoch 68, Iteration 7
# Train Loss: 3.85
# Accuracy: 77.34%
#
# Epoch 68, Iteration 8
# Train Loss: 3.43
# Accuracy: 82.03%
#
# Epoch 68, Iteration 9
# Train Loss: 3.47
# Accuracy: 80.47%
#
# Epoch 68, Iteration 10
# Train Loss: 4.17
# Accuracy: 78.69%
#
# 0.26197916666666665
# Accuracy: 26.20%
#
# Epoch 69, Iteration 0
# Train Loss: 4.23
# Accuracy: 67.19%
#
# Epoch 69, Iteration 1
# Train Loss: 3.53
# Accuracy: 75.00%
#
# Epoch 69, Iteration 2
# Train Loss: 3.77
# Accuracy: 75.78%
#
# Epoch 69, Iteration 3
# Train Loss: 3.99
# Accuracy: 75.00%
#
# Epoch 69, Iteration 4
# Train Loss: 3.43
# Accuracy: 81.25%
#
# Epoch 69, Iteration 5
# Train Loss: 3.59
# Accuracy: 80.47%
#
# Epoch 69, Iteration 6
# Train Loss: 4.01
# Accuracy: 75.00%
#
# Epoch 69, Iteration 7
# Train Loss: 3.65
# Accuracy: 78.12%
#
# Epoch 69, Iteration 8
# Train Loss: 3.74
# Accuracy: 78.12%
#
# Epoch 69, Iteration 9
# Train Loss: 3.82
# Accuracy: 78.12%
#
# Epoch 69, Iteration 10
# Train Loss: 3.25
# Accuracy: 86.89%
#
# 0.2230902777777778
# Accuracy: 22.31%
#
# Epoch 70, Iteration 0
# Train Loss: 3.12
# Accuracy: 82.81%
#
# Epoch 70, Iteration 1
# Train Loss: 3.92
# Accuracy: 74.22%
#
# Epoch 70, Iteration 2
# Train Loss: 3.89
# Accuracy: 74.22%
#
# Epoch 70, Iteration 3
# Train Loss: 3.51
# Accuracy: 78.12%
#
# Epoch 70, Iteration 4
# Train Loss: 3.90
# Accuracy: 73.44%
#
# Epoch 70, Iteration 5
# Train Loss: 3.93
# Accuracy: 71.88%
#
# Epoch 70, Iteration 6
# Train Loss: 4.18
# Accuracy: 76.56%
#
# Epoch 70, Iteration 7
# Train Loss: 3.70
# Accuracy: 78.91%
#
# Epoch 70, Iteration 8
# Train Loss: 3.84
# Accuracy: 72.66%
#
# Epoch 70, Iteration 9
# Train Loss: 3.43
# Accuracy: 78.91%
#
# Epoch 70, Iteration 10
# Train Loss: 4.28
# Accuracy: 72.13%
#
# 0.2309027777777778
# Accuracy: 23.09%
#
# Epoch 71, Iteration 0
# Train Loss: 3.54
# Accuracy: 76.56%
#
# Epoch 71, Iteration 1
# Train Loss: 3.80
# ...
#
# Epoch 76, Iteration 4
# Train Loss: 3.67
# Accuracy: 79.69%
#
# Epoch 76, Iteration 5
# Train Loss: 3.48
# Accuracy: 82.81%
#
# Epoch 76, Iteration 6
# Train Loss: 3.31
# Accuracy: 85.94%
#
# Epoch 76, Iteration 7
# Train Loss: 3.69
# Accuracy: 79.69%
#
# Epoch 76, Iteration 8
# Train Loss: 3.26
# Accuracy: 83.59%
#
# Epoch 76, Iteration 9
# Train Loss: 3.32
# Accuracy: 84.38%
#
# Epoch 76, Iteration 10
# Train Loss: 4.17
# Accuracy: 77.05%
#
# 0.23350694444444445
# Accuracy: 23.35%
#
# Epoch 77, Iteration 0
# Train Loss: 3.23
# Accuracy: 83.59%
#
# Epoch 77, Iteration 1
# Train Loss: 3.59
# Accuracy: 78.12%
#
# Epoch 77, Iteration 2
# Train Loss: 3.59
# Accuracy: 80.47%
#
# Epoch 77, Iteration 3
# Train Loss: 3.07
# Accuracy: 85.16%
#
# Epoch 77, Iteration 4
# Train Loss: 3.87
# Accuracy: 75.78%
#
# Epoch 77, Iteration 5
# Train Loss: 3.23
# Accuracy: 84.38%
#
# Epoch 77, Iteration 6
# Train Loss: 3.88
# Accuracy: 73.44%
#
# Epoch 77, Iteration 7
# Train Loss: 3.37
# Accuracy: 78.91%
#
# Epoch 77, Iteration 8
# Train Loss: 3.51
# Accuracy: 80.47%
#
# Epoch 77, Iteration 9
# Train Loss: 3.35
# Accuracy: 83.59%
#
# Epoch 77, Iteration 10
# Train Loss: 3.70
# Accuracy: 70.49%
#
# 0.2599826388888889
# Accuracy: 26.00%
#
# Epoch 78, Iteration 0
# Train Loss: 3.64
# Accuracy: 78.12%
#
# Epoch 78, Iteration 1
# Train Loss: 3.27
# Accuracy: 81.25%
#
# Epoch 78, Iteration 2
# Train Loss: 3.40
# Accuracy: 83.59%
#
# Epoch 78, Iteration 3
# Train Loss: 3.86
# Accuracy: 76.56%
#
# Epoch 78, Iteration 4
# Train Loss: 3.68
# Accuracy: 80.47%
#
# Epoch 78, Iteration 5
# Train Loss: 3.44
# Accuracy: 80.47%
#
# Epoch 78, Iteration 6
# Train Loss: 3.43
# Accuracy: 78.91%
#
# Epoch 78, Iteration 7
# Train Loss: 3.45
# Accuracy: 80.47%
#
# Epoch 78, Iteration 8
# Train Loss: 3.48
# Accuracy: 82.03%
#
# Epoch 78, Iteration 9
# Train Loss: 3.53
# Accuracy: 75.78%
#
# Epoch 78, Iteration 10
# Train Loss: 3.60
# Accuracy: 75.41%
#
# 0.2269965277777778
# Accuracy: 22.70%
#
# Epoch 79, Iteration 0
# Train Loss: 3.17
# Accuracy: 86.72%
#
# Epoch 79, Iteration 1
# Train Loss: 3.38
# Accuracy: 81.25%
#
# Epoch 79, Iteration 2
# Train Loss: 3.59
# Accuracy: 80.47%
#
# Epoch 79, Iteration 3
# Train Loss: 3.41
# Accuracy: 77.34%
#
# Epoch 79, Iteration 4
# Train Loss: 3.42
# Accuracy: 81.25%
#
# Epoch 79, Iteration 5
# Train Loss: 3.64
# Accuracy: 76.56%
#
# Epoch 79, Iteration 6
# Train Loss: 3.36
# Accuracy: 79.69%
#
# Epoch 79, Iteration 7
# Train Loss: 3.64
# Accuracy: 81.25%
#
# Epoch 79, Iteration 8
# Train Loss: 3.72
# Accuracy: 80.47%
#
# Epoch 79, Iteration 9
# Train Loss: 3.35
# Accuracy: 79.69%
#
# Epoch 79, Iteration 10
# Train Loss: 3.81
# Accuracy: 73.77%
#
# 0.24010416666666667
# Accuracy: 24.01%
#
# Epoch 80, Iteration 0
# Train Loss: 3.53
# Accuracy: 78.12%
#
# Epoch 80, Iteration 1
# Train Loss: 3.47
# Accuracy: 82.81%
#
# Epoch 80, Iteration 2
# Train Loss: 3.36
# Accuracy: 82.81%
#
# Epoch 80, Iteration 3
# Train Loss: 3.58
# Accuracy: 80.47%
#
# Epoch 80, Iteration 4
# Train Loss: 3.94
# Accuracy: 70.31%
#
# Epoch 80, Iteration 5
# Train Loss: 3.63
# Accuracy: 78.12%
#
# Epoch 80, Iteration 6
# Train Loss: 3.28
# Accuracy: 84.38%
#
# Epoch 80, Iteration 7
# Train Loss: 3.31
# Accuracy: 80.47%
#
# Epoch 80, Iteration 8
# Train Loss: 3.74
# Accuracy: 75.78%
#
# Epoch 80, Iteration 9
# Train Loss: 3.89
# Accuracy: 71.09%
#
# Epoch 80, Iteration 10
# Train Loss: 3.89
# Accuracy: 77.05%
#
# 0.24392361111111113
# Accuracy: 24.39%
#
# Epoch 81, Iteration 0
# Train Loss: 3.31
# Accuracy: 82.81%
#
# Epoch 81, Iteration 1
# Train Loss: 3.83
# Accuracy: 78.12%
#
# Epoch 81, Iteration 2
# Train Loss: 3.02
# Accuracy: 87.50%
#
# Epoch 81, Iteration 3
# Train Loss: 3.15
# Accuracy: 82.81%
#
# Epoch 81, Iteration 4
# Train Loss: 3.55
# Accuracy: 80.47%
#
# Epoch 81, Iteration 5
# Train Loss: 3.82
# Accuracy: 74.22%
#
# Epoch 81, Iteration 6
# Train Loss: 3.34
# Accuracy: 84.38%
#
# Epoch 81, Iteration 7
# Train Loss: 3.54
# Accuracy: 77.34%
#
# Epoch 81, Iteration 8
# Train Loss: 3.50
# Accuracy: 78.91%
#
# Epoch 81, Iteration 9
# Train Loss: 3.65
# Accuracy: 77.34%
#
# Epoch 81, Iteration 10
# Train Loss: 3.37
# Accuracy: 86.89%
#
# 0.24166666666666667
# Accuracy: 24.17%
#
# Epoch 82, Iteration 0
# Train Loss: 3.25
# Accuracy: 78.91%
#
# Epoch 82, Iteration 1
# Train Loss: 3.35
# Accuracy: 81.25%
#
# Epoch 82, Iteration 2
# Train Loss: 3.33
# Accuracy: 84.38%
#
# Epoch 82, Iteration 3
# Train Loss: 3.54
# Accuracy: 75.78%
#
# Epoch 82, Iteration 4
# Train Loss: 3.35
# Accuracy: 81.25%
#
# Epoch 82, Iteration 5
# Train Loss: 3.62
# Accuracy: 82.03%
#
# Epoch 82, Iteration 6
# Train Loss: 3.67
# Accuracy: 78.12%
#
# Epoch 82, Iteration 7
# Train Loss: 3.46
# Accuracy: 78.91%
#
# Epoch 82, Iteration 8
# Train Loss: 3.58
# Accuracy: 78.12%
#
# Epoch 82, Iteration 9
# Train Loss: 3.11
# Accuracy: 85.94%
#
# Epoch 82, Iteration 10
# Train Loss: 3.15
# Accuracy: 85.25%
#
# 0.23185763888888888
# Accuracy: 23.19%
#
# Epoch 83, Iteration 0
# Train Loss: 2.88
# Accuracy: 84.38%
#
# Epoch 83, Iteration 1
# Train Loss: 3.29
# Accuracy: 82.81%
#
# Epoch 83, Iteration 2
# Train Loss: 3.80
# Accuracy: 71.88%
#
# Epoch 83, Iteration 3
# Train Loss: 3.68
# Accuracy: 80.47%
#
# Epoch 83, Iteration 4
# Train Loss: 3.60
# Accuracy: 75.78%
#
# Epoch 83, Iteration 5
# Train Loss: 3.19
# Accuracy: 82.03%
#
# Epoch 83, Iteration 6
# Train Loss: 3.72
# Accuracy: 76.56%
#
# Epoch 83, Iteration 7
# Train Loss: 3.32
# Accuracy: 84.38%
#
# Epoch 83, Iteration 8
# Train Loss: 3.26
# Accuracy: 83.59%
#
# Epoch 83, Iteration 9
# Train Loss: 3.77
# Accuracy: 75.78%
#
# Epoch 83, Iteration 10
# Train Loss: 3.92
# Accuracy: 78.69%
#
# 0.27960069444444446
# Accuracy: 27.96%
#
# Epoch 84, Iteration 0
# Train Loss: 3.19
# Accuracy: 85.94%
#
# Epoch 84, Iteration 1
# Train Loss: 3.58
# Accuracy: 82.81%
#
# Epoch 84, Iteration 2
# Train Loss: 3.38
# Accuracy: 83.59%
#
# Epoch 84, Iteration 3
# Train Loss: 3.06
# Accuracy: 85.16%
#
# Epoch 84, Iteration 4
# Train Loss: 3.74
# Accuracy: 80.47%
#
# Epoch 84, Iteration 5
# Train Loss: 3.32
# Accuracy: 79.69%
#
# Epoch 84, Iteration 6
# Train Loss: 3.23
# Accuracy: 81.25%
#
# Epoch 84, Iteration 7
# Train Loss: 3.60
# Accuracy: 76.56%
#
# Epoch 84, Iteration 8
# Train Loss: 3.27
# Accuracy: 81.25%
#
# Epoch 84, Iteration 9
# Train Loss: 3.58
# Accuracy: 78.12%
#
# Epoch 84, Iteration 10
# Train Loss: 3.64
# Accuracy: 70.49%
#
# 0.2387152777777778
# Accuracy: 23.87%
#
# Epoch 85, Iteration 0
# Train Loss: 3.42
# Accuracy: 82.03%
#
# Epoch 85, Iteration 1
# Train Loss: 3.24
# Accuracy: 82.81%
#
# Epoch 85, Iteration 2
# Train Loss: 4.15
# Accuracy: 72.66%
#
# Epoch 85, Iteration 3
# Train Loss: 3.37
# Accuracy: 81.25%
#
# Epoch 85, Iteration 4
# Train Loss: 3.67
# Accuracy: 76.56%
#
# Epoch 85, Iteration 5
# Train Loss: 3.44
# Accuracy: 75.78%
#
# Epoch 85, Iteration 6
# Train Loss: 3.26
# Accuracy: 82.81%
#
# Epoch 85, Iteration 7
# Train Loss: 3.26
# Accuracy: 81.25%
#
# Epoch 85, Iteration 8
# Train Loss: 3.39
# Accuracy: 78.91%
#
# Epoch 85, Iteration 9
# Train Loss: 3.17
# Accuracy: 82.03%
#
# Epoch 85, Iteration 10
# Train Loss: 3.60
# Accuracy: 81.97%
#
# 0.2690972222222222
# Accuracy: 26.91%
#
# Epoch 86, Iteration 0
# Train Loss: 3.49
# Accuracy: 83.59%
#
# Epoch 86, Iteration 1
# Train Loss: 3.42
# Accuracy: 75.78%
#
# Epoch 86, Iteration 2
# Train Loss: 3.22
# Accuracy: 84.38%
#
# Epoch 86, Iteration 3
# Train Loss: 3.51
# Accuracy: 81.25%
#
# Epoch 86, Iteration 4
# Train Loss: 3.29
# Accuracy: 82.03%
#
# Epoch 86, Iteration 5
# Train Loss: 3.40
# Accuracy: 80.47%
#
# Epoch 86, Iteration 6
# Train Loss: 3.42
# Accuracy: 81.25%
#
# Epoch 86, Iteration 7
# Train Loss: 3.85
# Accuracy: 75.00%
#
# Epoch 86, Iteration 8
# Train Loss: 3.46
# Accuracy: 78.12%
#
# Epoch 86, Iteration 9
# Train Loss: 3.34
# Accuracy: 75.78%
#
# Epoch 86, Iteration 10
# Train Loss: 2.75
# Accuracy: 91.80%
#
# 0.2420138888888889
# Accuracy: 24.20%
#
# Epoch 87, Iteration 0
# Train Loss: 3.59
# Accuracy: 75.78%
#
# Epoch 87, Iteration 1
# Train Loss: 3.81
# Accuracy: 75.78%
#
# Epoch 87, Iteration 2
# Train Loss: 3.46
# Accuracy: 75.00%
#
# Epoch 87, Iteration 3
# Train Loss: 3.65
# Accuracy: 78.12%
#
# Epoch 87, Iteration 4
# Train Loss: 3.27
# Accuracy: 84.38%
#
# Epoch 87, Iteration 5
# Train Loss: 3.13
# Accuracy: 85.94%
#
# Epoch 87, Iteration 6
# Train Loss: 3.82
# Accuracy: 70.31%
#
# Epoch 87, Iteration 7
# Train Loss: 3.74
# Accuracy: 75.78%
#
# Epoch 87, Iteration 8
# Train Loss: 3.63
# Accuracy: 81.25%
#
# Epoch 87, Iteration 9
# Train Loss: 3.39
# Accuracy: 79.69%
#
# Epoch 87, Iteration 10
# Train Loss: 3.15
# Accuracy: 85.25%
#
# 0.26710069444444445
# Accuracy: 26.71%
#
# Epoch 88, Iteration 0
# Train Loss: 3.66
# Accuracy: 76.56%
#
# Epoch 88, Iteration 1
# Train Loss: 3.69
# Accuracy: 79.69%
#
# Epoch 88, Iteration 2
# Train Loss: 3.18
# Accuracy: 85.94%
#
# Epoch 88, Iteration 3
# Train Loss: 3.44
# Accuracy: 79.69%
#
# Epoch 88, Iteration 4
# Train Loss: 3.59
# Accuracy: 82.03%
#
# Epoch 88, Iteration 5
# Train Loss: 3.73
# Accuracy: 78.12%
#
# Epoch 88, Iteration 6
# Train Loss: 3.64
# Accuracy: 77.34%
#
# Epoch 88, Iteration 7
# Train Loss: 3.42
# Accuracy: 81.25%
#
# Epoch 88, Iteration 8
# Train Loss: 3.62
# Accuracy: 77.34%
#
# Epoch 88, Iteration 9
# Train Loss: 3.49
# Accuracy: 82.81%
#
# Epoch 88, Iteration 10
# Train Loss: 3.14
# Accuracy: 88.52%
#
# 0.24296874999999998
# Accuracy: 24.30%
#
# Epoch 89, Iteration 0
# Train Loss: 3.36
# Accuracy: 80.47%
#
# Epoch 89, Iteration 1
# Train Loss: 3.60
# Accuracy: 80.47%
#
# Epoch 89, Iteration 2
# Train Loss: 3.73
# Accuracy: 79.69%
#
# Epoch 89, Iteration 3
# Train Loss: 3.27
# Accuracy: 82.03%
#
# Epoch 89, Iteration 4
# Train Loss: 3.69
# Accuracy: 75.00%
#
# Epoch 89, Iteration 5
# Train Loss: 3.43
# Accuracy: 85.16%
#
# Epoch 89, Iteration 6
# Train Loss: 3.11
# Accuracy: 84.38%
#
# Epoch 89, Iteration 7
# Train Loss: 3.49
# Accuracy: 76.56%
#
# Epoch 89, Iteration 8
# Train Loss: 3.36
# Accuracy: 83.59%
#
# Epoch 89, Iteration 9
# Train Loss: 3.19
# Accuracy: 84.38%
#
# Epoch 89, Iteration 10
# Train Loss: 3.10
# Accuracy: 83.61%
#
# 0.23220486111111113
# Accuracy: 23.22%
#
# Epoch 90, Iteration 0
# Train Loss: 3.21
# Accuracy: 87.50%
#
# Epoch 90, Iteration 1
# Train Loss: 3.18
# Accuracy: 80.47%
#
# Epoch 90, Iteration 2
# Train Loss: 3.67
# Accuracy: 73.44%
#
# Epoch 90, Iteration 3
# Train Loss: 3.62
# Accuracy: 78.91%
#
# Epoch 90, Iteration 4
# Train Loss: 3.33
# Accuracy: 82.81%
#
# Epoch 90, Iteration 5
# Train Loss: 3.17
# Accuracy: 84.38%
#
# Epoch 90, Iteration 6
# Train Loss: 3.37
# Accuracy: 83.59%
#
# Epoch 90, Iteration 7
# Train Loss: 3.70
# Accuracy: 76.56%
#
# Epoch 90, Iteration 8
# Train Loss: 3.38
# Accuracy: 78.12%
#
# Epoch 90, Iteration 9
# Train Loss: 3.29
# Accuracy: 84.38%
#
# Epoch 90, Iteration 10
# Train Loss: 3.00
# Accuracy: 81.97%
#
# 0.24036458333333333
# Accuracy: 24.04%
#
# Epoch 91, Iteration 0
# Train Loss: 3.67
# Accuracy: 78.12%
#
# Epoch 91, Iteration 1
# Train Loss: 3.28
# Accuracy: 84.38%
#
# Epoch 91, Iteration 2
# Train Loss: 3.53
# Accuracy: 81.25%
#
# Epoch 91, Iteration 3
# Train Loss: 3.16
# Accuracy: 83.59%
#
# Epoch 91, Iteration 4
# Train Loss: 3.13
# Accuracy: 82.03%
#
# Epoch 91, Iteration 5
# Train Loss: 3.15
# Accuracy: 89.06%
#
# Epoch 91, Iteration 6
# Train Loss: 3.38
# Accuracy: 81.25%
#
# Epoch 91, Iteration 7
# Train Loss: 3.29
# Accuracy: 82.81%
#
# Epoch 91, Iteration 8
# Train Loss: 3.38
# Accuracy: 80.47%
#
# Epoch 91, Iteration 9
# Train Loss: 3.09
# Accuracy: 84.38%
#
# Epoch 91, Iteration 10
# Train Loss: 3.31
# Accuracy: 83.61%
#
# 0.2579861111111111
# Accuracy: 25.80%
#
# Epoch 92, Iteration 0
# Train Loss: 3.33
# Accuracy: 82.03%
#
# Epoch 92, Iteration 1
# Train Loss: 3.12
# Accuracy: 82.81%
#
# Epoch 92, Iteration 2
# Train Loss: 3.50
# Accuracy: 80.47%
#
# Epoch 92, Iteration 3
# Train Loss: 3.04
# Accuracy: 83.59%
#
# Epoch 92, Iteration 4
# Train Loss: 3.19
# Accuracy: 85.16%
#
# Epoch 92, Iteration 5
# Train Loss: 3.29
# Accuracy: 82.81%
#
# Epoch 92, Iteration 6
# Train Loss: 3.32
# Accuracy: 82.03%
#
# Epoch 92, Iteration 7
# Train Loss: 3.37
# Accuracy: 85.94%
#
# Epoch 92, Iteration 8
# Train Loss: 3.54
# Accuracy: 78.91%
#
# Epoch 92, Iteration 9
# Train Loss: 3.40
# Accuracy: 82.03%
#
# Epoch 92, Iteration 10
# Train Loss: 3.52
# Accuracy: 78.69%
#
# 0.25668402777777777
# Accuracy: 25.67%
#
# Epoch 93, Iteration 0
# Train Loss: 3.65
# Accuracy: 78.12%
#
# Epoch 93, Iteration 1
# Train Loss: 3.23
# Accuracy: 84.38%
#
# Epoch 93, Iteration 2
# Train Loss: 3.36
# Accuracy: 80.47%
#
# Epoch 93, Iteration 3
# Train Loss: 3.33
# Accuracy: 82.03%
#
# Epoch 93, Iteration 4
# Train Loss: 3.48
# Accuracy: 78.91%
#
# Epoch 93, Iteration 5
# Train Loss: 3.51
# Accuracy: 79.69%
#
# Epoch 93, Iteration 6
# Train Loss: 3.23
# Accuracy: 81.25%
#
# Epoch 93, Iteration 7
# Train Loss: 3.30
# Accuracy: 86.72%
#
# Epoch 93, Iteration 8
# Train Loss: 3.08
# Accuracy: 85.16%
#
# Epoch 93, Iteration 9
# Train Loss: 3.18
# Accuracy: 82.03%
#
# Epoch 93, Iteration 10
# Train Loss: 3.27
# Accuracy: 83.61%
#
# 0.2508680555555555
# Accuracy: 25.09%
#
# Epoch 94, Iteration 0
# Train Loss: 3.50
# Accuracy: 79.69%
#
# Epoch 94, Iteration 1
# Train Loss: 3.42
# Accuracy: 79.69%
#
# Epoch 94, Iteration 2
# Train Loss: 3.24
# Accuracy: 81.25%
#
# Epoch 94, Iteration 3
# Train Loss: 3.35
# Accuracy: 79.69%
#
# Epoch 94, Iteration 4
# Train Loss: 3.40
# Accuracy: 82.81%
#
# Epoch 94, Iteration 5
# Train Loss: 3.24
# Accuracy: 80.47%
#
# Epoch 94, Iteration 6
# Train Loss: 3.50
# Accuracy: 82.81%
#
# Epoch 94, Iteration 7
# Train Loss: 3.26
# Accuracy: 85.16%
#
# Epoch 94, Iteration 8
# Train Loss: 3.19
# Accuracy: 86.72%
#
# Epoch 94, Iteration 9
# Train Loss: 3.21
# Accuracy: 82.81%
#
# Epoch 94, Iteration 10
# Train Loss: 2.80
# Accuracy: 86.89%
#
# 0.22569444444444445
# Accuracy: 22.57%
#
# Epoch 95, Iteration 0
# Train Loss: 3.18
# Accuracy: 82.03%
#
# Epoch 95, Iteration 1
# Train Loss: 3.17
# Accuracy: 84.38%
#
# Epoch 95, Iteration 2
# Train Loss: 3.28
# Accuracy: 81.25%
#
# Epoch 95, Iteration 3
# Train Loss: 3.41
# Accuracy: 84.38%
#
# Epoch 95, Iteration 4
# Train Loss: 3.24
# Accuracy: 85.16%
#
# Epoch 95, Iteration 5
# Train Loss: 2.96
# Accuracy: 88.28%
#
# Epoch 95, Iteration 6
# Train Loss: 3.48
# Accuracy: 80.47%
#
# Epoch 95, Iteration 7
# Train Loss: 3.38
# Accuracy: 85.16%
#
# Epoch 95, Iteration 8
# Train Loss: 3.29
# Accuracy: 82.81%
#
# Epoch 95, Iteration 9
# Train Loss: 3.39
# Accuracy: 77.34%
#
# Epoch 95, Iteration 10
# Train Loss: 3.07
# Accuracy: 83.61%
#
# 0.24947916666666667
# Accuracy: 24.95%
#
# Epoch 96, Iteration 0
# Train Loss: 3.39
# Accuracy: 82.81%
#
# Epoch 96, Iteration 1
# Train Loss: 3.37
# Accuracy: 78.12%
#
# Epoch 96, Iteration 2
# Train Loss: 3.16
# Accuracy: 83.59%
#
# Epoch 96, Iteration 3
# Train Loss: 2.90
# Accuracy: 88.28%
#
# Epoch 96, Iteration 4
# Train Loss: 3.22
# Accuracy: 85.94%
#
# Epoch 96, Iteration 5
# Train Loss: 3.28
# Accuracy: 85.16%
#
# Epoch 96, Iteration 6
# Train Loss: 3.60
# Accuracy: 79.69%
#
# Epoch 96, Iteration 7
# Train Loss: 2.98
# Accuracy: 85.16%
#
# Epoch 96, Iteration 8
# Train Loss: 3.00
# Accuracy: 84.38%
#
# Epoch 96, Iteration 9
# Train Loss: 3.14
# Accuracy: 81.25%
#
# Epoch 96, Iteration 10
# Train Loss: 3.51
# Accuracy: 77.05%
#
# 0.24852430555555557
# Accuracy: 24.85%
#
# Epoch 97, Iteration 0
# Train Loss: 3.01
# Accuracy: 83.59%
#
# Epoch 97, Iteration 1
# Train Loss: 3.14
# Accuracy: 87.50%
#
# Epoch 97, Iteration 2
# Train Loss: 3.43
# Accuracy: 83.59%
#
# Epoch 97, Iteration 3
# Train Loss: 2.83
# Accuracy: 89.06%
#
# Epoch 97, Iteration 4
# Train Loss: 3.23
# Accuracy: 82.03%
#
# Epoch 97, Iteration 5
# Train Loss: 2.94
# Accuracy: 89.06%
#
# Epoch 97, Iteration 6
# Train Loss: 3.21
# Accuracy: 85.16%
#
# Epoch 97, Iteration 7
# Train Loss: 3.21
# Accuracy: 83.59%
#
# Epoch 97, Iteration 8
# Train Loss: 3.27
# Accuracy: 82.03%
#
# Epoch 97, Iteration 9
# Train Loss: 3.57
# Accuracy: 78.91%
#
# Epoch 97, Iteration 10
# Train Loss: 3.27
# Accuracy: 81.97%
#
# 0.23975694444444443
# Accuracy: 23.98%
#
# Epoch 98, Iteration 0
# Train Loss: 3.31
# Accuracy: 79.69%
#
# Epoch 98, Iteration 1
# Train Loss: 3.19
# Accuracy: 82.03%
#
# Epoch 98, Iteration 2
# Train Loss: 3.06
# Accuracy: 85.16%
#
# Epoch 98, Iteration 3
# Train Loss: 3.12
# Accuracy: 82.03%
#
# Epoch 98, Iteration 4
# Train Loss: 3.59
# Accuracy: 77.34%
#
# Epoch 98, Iteration 5
# Train Loss: 3.71
# Accuracy: 81.25%
#
# Epoch 98, Iteration 6
# Train Loss: 3.33
# Accuracy: 81.25%
#
# Epoch 98, Iteration 7
# Train Loss: 3.04
# Accuracy: 85.94%
#
# Epoch 98, Iteration 8
# Train Loss: 3.12
# Accuracy: 84.38%
#
# Epoch 98, Iteration 9
# Train Loss: 3.25
# Accuracy: 87.50%
#
# Epoch 98, Iteration 10
# Train Loss: 3.08
# Accuracy: 81.97%
#
# 0.23706597222222223
# Accuracy: 23.71%
#
# Epoch 99, Iteration 0
# Train Loss: 3.13
# Accuracy: 82.81%
#
# Epoch 99, Iteration 1
# Train Loss: 3.28
# Accuracy: 79.69%
#
# Epoch 99, Iteration 2
# Train Loss: 3.05
# Accuracy: 82.81%
#
# Epoch 99, Iteration 3
# Train Loss: 3.24
# Accuracy: 85.94%
#
# Epoch 99, Iteration 4
# Train Loss: 2.99
# Accuracy: 85.16%
#
# Epoch 99, Iteration 5
# Train Loss: 3.34
# Accuracy: 85.16%
#
# Epoch 99, Iteration 6
# Train Loss: 3.18
# Accuracy: 85.16%
#
# Epoch 99, Iteration 7
# Train Loss: 3.29
# Accuracy: 81.25%
#
# Epoch 99, Iteration 8
# Train Loss: 2.70
# Accuracy: 92.19%
#
# Epoch 99, Iteration 9
# Train Loss: 3.25
# Accuracy: 85.16%
#
# Epoch 99, Iteration 10
# Train Loss: 3.75
# Accuracy: 81.97%
#
# 0.26484375
# Accuracy: 26.48%

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams["figure.figsize"] = (5,7)
fig, (ax1, ax3) = plt.subplots(2, 1)

x_tics = np.arange(0, 20, 1)

ax2 = ax1.twinx()
ax1.plot(loss_hist, 'b-')
ax2.plot(acc_hist, 'r-')

ax1.set_xlabel('Iterations')
ax1.set_ylabel('Loss', color='b')
ax2.set_ylabel('Accuracy', color='r')

ax4 = ax3.twinx()
ax3.plot(loss_epoch, 'b-')
ax4.plot(acc_epoch, 'r-')
ax4.plot(eval_acc_epoch, 'y-')

ax3.set_xlabel('Epochs')
ax3.set_ylabel('Loss', color='b')
ax4.set_ylabel('Accuracy', color='r')

plt.xticks(np.arange(0, num_epochs, 2))
plt.show()

# %% [markdown]
# # Conf matrix on training data

# %%
eval_acc = []
all_labels = []
all_preds = []
total_correct = 0
total = 0
acc_tmp = []
for i, (data, targets) in enumerate(iter(train_loader)):
    data, targets = data.to(device), targets.to(device)
    data = data.permute(2, 0, 1)
    net.eval()
    spk_rec = forward_pass(net, data)

    total += targets.size(0)
    acc = snn.functional.accuracy_rate(spk_rec, targets)
    _, idx = spk_rec.sum(dim=0).max(1)
    total_correct += (targets == idx).detach().cpu().numpy().sum().item()
    acc_tmp.append(acc)

    all_labels.extend(targets.cpu().numpy())
    #all_preds.extend(predicted.cpu().numpy())
    all_preds.extend(idx.cpu().numpy())

    accuracy = 100 * total_correct / total
    acc = SF.accuracy_rate(spk_rec, targets)
    eval_acc.append(acc)
eval_acc_tot = sum(eval_acc) / len(eval_acc)
print(eval_acc_tot)
cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Up", "Down", "Right", "Left"], yticklabels=["Up", "Down", "Right", "Left"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# 0.8501536885245902

# %% [markdown]
# # Conf matrix on valid data

# %%
eval_acc = []
all_labels = []
all_preds = []
total_correct = 0
total = 0
acc_tmp = []
for i, (data, targets) in enumerate(iter(val_loader)):
    data, targets = data.to(device), targets.to(device)
    data = data.permute(2, 0, 1)
    net.eval()
    spk_rec = forward_pass(net, data)

    total += targets.size(0)
    acc = snn.functional.accuracy_rate(spk_rec, targets)
    _, idx = spk_rec.sum(dim=0).max(1)
    total_correct += (targets == idx).detach().cpu().numpy().sum().item()
    acc_tmp.append(acc)

    all_labels.extend(targets.cpu().numpy())
    #all_preds.extend(predicted.cpu().numpy())
    all_preds.extend(idx.cpu().numpy())

    accuracy = 100 * total_correct / total
    acc = SF.accuracy_rate(spk_rec, targets)
    eval_acc.append(acc)
eval_acc_tot = sum(eval_acc) / len(eval_acc)
print(eval_acc_tot)
cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Up", "Down", "Right", "Left"], yticklabels=["Up", "Down", "Right", "Left"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# 0.25633680555555555

# %% [markdown]
# # Conf matrix on testing data

# %%
eval_acc = []
all_labels = []
all_preds = []
total_correct = 0
total = 0
acc_tmp = []
for i, (data, targets) in enumerate(iter(test_loader)):
    data, targets = data.to(device), targets.to(device)
    data = data.permute(2, 0, 1)
    net.eval()
    spk_rec = forward_pass(net, data)

    total += targets.size(0)
    acc = snn.functional.accuracy_rate(spk_rec, targets)
    _, idx = spk_rec.sum(dim=0).max(1)
    total_correct += (targets == idx).detach().cpu().numpy().sum().item()
    acc_tmp.append(acc)

    all_labels.extend(targets.cpu().numpy())
    #all_preds.extend(predicted.cpu().numpy())
    all_preds.extend(idx.cpu().numpy())

    accuracy = 100 * total_correct / total
    acc = SF.accuracy_rate(spk_rec, targets)
    eval_acc.append(acc)
eval_acc_tot = sum(eval_acc) / len(eval_acc)
print(eval_acc_tot)
cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Up", "Down", "Right", "Left"], yticklabels=["Up", "Down", "Right", "Left"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# 0.3197889819587629
